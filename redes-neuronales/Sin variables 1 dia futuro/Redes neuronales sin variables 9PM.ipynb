# %% [markdown]
# # Predicción de la temperatura

# %% [markdown]
# ## Descarga de datos csv y scripts

# %%
# !rm -rf logs
# !rm -rf data
# !rm -rf regresion
# !rm -rf utilidades
# !rm -rf redes-exp*

# %%
# !wget https://github.com/rodrigofvc/prediccion-temp-mexico/archive/refs/heads/main.zip

import zipfile

with zipfile.ZipFile("main.zip","r") as zip_ref:
  zip_ref.extractall(".")

# !cp -rf "/content/prediccion-temp-mexico-main/data" "."
# !cp -rf "/content/prediccion-temp-mexico-main/regresion" "."
# !cp -rf "/content/prediccion-temp-mexico-main/utilidades" "."
# !rm -rf "prediccion-temp-mexico-main"
# !rm -rf "sample_data"
# !rm "main.zip"
# Out:
# --2022-11-28 05:41:13--  https://github.com/rodrigofvc/prediccion-temp-mexico/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/rodrigofvc/prediccion-temp-mexico/zip/refs/heads/main [following]
# --2022-11-28 05:41:13--  https://codeload.github.com/rodrigofvc/prediccion-temp-mexico/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.27.177.114
# Connecting to codeload.github.com (codeload.github.com)|20.27.177.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [            <=>     ] 773.93M  13.3MB/s    in 42s
#
# 2022-11-28 05:41:56 (18.3 MB/s) - ‘main.zip’ saved [811529884]

# %% [markdown]
# ## Import de scripts

# %%
from utilidades.Lector_Futuro import Lector_Futuro
from utilidades.Lector import Lector
import sys

# %% [markdown]
# ## Modelo de redes neuronales

# %% [markdown]
# ### Import de bibliotecas necesarias

# %%
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.8.3.post1-py3-none-any.whl (798 kB)
#      |████████████████████████████████| 798 kB 4.3 MB/s
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.64.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.21.6)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      |████████████████████████████████| 529 kB 52.9 MB/s
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2022.11.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.1.1)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 52.5 MB/s
# Requirement already satisfied: torch>=1.9.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.12.1+cu113)
# Collecting lightning-utilities==0.3.*
#   Downloading lightning_utilities-0.3.0-py3-none-any.whl (15 kB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 892 kB/s
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.1.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (0.13.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (3.0.9)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX>=2.2->pytorch-lightning) (3.19.6)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire->lightning-utilities==0.3.*->pytorch-lightning) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire->lightning-utilities==0.3.*->pytorch-lightning) (2.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.9.24)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=2bd1935ba4624d871eccb1441a4e84a9340aff82ff4b78bdd0df15176e8f4005
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# Installing collected packages: fire, torchmetrics, tensorboardX, lightning-utilities, pytorch-lightning
# Successfully installed fire-0.4.0 lightning-utilities-0.3.0 pytorch-lightning-1.8.3.post1 tensorboardX-2.5.1 torchmetrics-0.10.3

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Utilerias
import os
import math
import random
import datetime
# Redes neuronales
import torch
import torch.nn as nn
import torch.optim as optim
# Matrices
import numpy as np
import pandas as pd
# Lightning
from pytorch_lightning import seed_everything
import pytorch_lightning as pl
import torch.nn.functional as F
from torchvision import datasets, transforms
from pytorch_lightning.loggers import TensorBoardLogger
from torchmetrics import MeanAbsoluteError
# Carga de datos
from torch.utils.data import DataLoader, TensorDataset
# TensorFlow
import tensorflow as tf

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### Establecer la semilla

# %%
SEED = 99
def set_seed(seed):
    """Initializes pseudo-random number generators."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
set_seed(SEED)

# %% [markdown]
# ### Definición del conjunto de datos
#
# https://pytorch-lightning.readthedocs.io/en/latest/data/datamodule.html

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

class Data_ENCB_90(pl.LightningDataModule):
  def __init__(self, hora, pasosPasado=1, pasosFuturo=1, excluirColumnasX=['Direcci�n del Viento (grados)','Direcci�n de r�faga (grados)'], agregarHoraLocalY=True, show=True):
    super(Data_ENCB_90, self).__init__()
    
    self.BATCH_SIZE = 128
    self.X = None
    self.Y = None
    self.Y_val_horaLocal = None
    self.ds_trn = None
    self.ds_val = None
    #self.ds_tst = None

    self.pasosPasado = pasosPasado
    self.pasosFuturo = pasosFuturo
    self.excluirColumnasX = excluirColumnasX
    self.hora = hora
    self.agregarHoraLocalY= agregarHoraLocalY
    self.show = show

  def prepare_data(self):
    # Lee los datos del directorio
    l = Lector_Futuro('data/encb-90-fusionado.csv')
    self.X, self.Y = l.get_data(self.hora, pasosPasado=self.pasosPasado, pasosFuturo=self.pasosFuturo, excluirColumnasX=self.excluirColumnasX, agregarHoraLocalY=True, show=self.show)
    
    # El conjunto de datos se filtra a un intervalo especifico
    lp = Lector('data/encb-90-fusionado.csv')
    fecha_cercana = "2022-10-03 " + self.hora
    fecha_lejana = "2022-08-14 " + self.hora
    X_out, Y_out = lp.intervalo(self.X, self.Y, fecha_cercana, fecha_lejana)
    self.X = X_out
    self.Y = Y_out
    #if(self.agregarHoraLocalY == True):
    #  self.Y_val_horaLocal = self.Y.iloc[:,-1:]
    #  self.Y = self.Y.iloc[:,:1]

  def setup(self, stage=None):

    # Se dividen los datos en prueba y entrenamiento
    X_train, X_test, y_train, y_test = train_test_split(self.X, self.Y, random_state=SEED)

    if(self.agregarHoraLocalY == True):
      self.Y_val_horaLocal = y_test.iloc[:,-1:]
      y_test = y_test.iloc[:,:1]
      y_train = y_train.iloc[:,:1]

    # Min Max scaler se entrena con X de entrenamiento
    scaler = MinMaxScaler()
    scaler.fit(X_train)

    # Se escalan ambos X (entrenamiento y prueba) con el scaler previamente
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Convierte los datos a un arreglo de números decimales
    X_train_scaled = np.array(X_train_scaled, dtype="float32")
    X_test_scaled = np.array(X_test_scaled, dtype="float32")
    y_train = np.array(y_train, dtype="float32")
    y_test = np.array(y_test, dtype="float32")

    # Convierte el arreglo a un tensor
    X_train_scaled = torch.tensor(X_train_scaled)
    X_test_scaled = torch.tensor(X_test_scaled)
    y_train = torch.tensor(y_train)
    y_test = torch.tensor(y_test)

    # Crea los Dataset de  entrenamiento y prueba
    self.ds_trn = TensorDataset(X_train_scaled, y_train)
    self.ds_val = TensorDataset(X_test_scaled, y_test)

    # Calcula el porcentaje 80/20
    #val_size = int(0.2 * len(dataSet))
    #train_size = len(dataSet) - val_size

    # Divide el Dataset en conjunto de entrenamiento y prueba (aleatorio)
    #self.ds_trn, self.ds_val = torch.utils.data.random_split(dataSet, [train_size, val_size], generator=torch.Generator().manual_seed(SEED))
    #self.Y_val_horaLocal = self.Y_val_horaLocal.iloc[dataTemp.ds_val.indices]

    # Divide el Dataset en conjunto de entrenamiento y prueba (sin aleatoriedad)
    #self.ds_val = torch.utils.data.Subset(dataSet, range(val_size))
    #self.ds_trn = torch.utils.data.Subset(dataSet, range(val_size, val_size + train_size))
    #self.Y_val_horaLocal = self.Y_val_horaLocal.iloc[range(val_size)]
    #self.ds_tst = torch.utils.data.Subset(dataSet, range(val_size + train_size, val_size + train_size + test_size))

  # Devuelte los datos de entrenamiento
  def train_dataloader(self):
    return DataLoader(self.ds_trn, batch_size=self.BATCH_SIZE, shuffle=False)
  
  # Devuelte los datos de validación
  def val_dataloader(self):
    return DataLoader(self.ds_val, batch_size=self.BATCH_SIZE, shuffle=False)

  # Devuelte los datos de prueba
  #def test_dataloader(self):
  #  return DataLoader(self.ds_tst, batch_size=self.BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### Muestras del conjunto de datos

# %%
dataTemp = Data_ENCB_90('09:00:00', pasosPasado=1, pasosFuturo=1, excluirColumnasX=["Direcci�n del Viento (grados)","Direcci�n de r�faga (grados)","Rapidez de viento (km/h)","Rapidez de r�faga (km/h)","Humedad relativa (%)","Presi�n Atmosf�rica (hpa)","Precipitaci�n (mm)","Radiaci�n Solar (W/m�)"])
dataTemp.prepare_data()
dataTemp.setup()
# Out:
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-11-11 09:00:00
# Datos de t-1 días antes: 2022-11-10 09:00:00 [15.9]
# Datos pasados final: [15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-11-10 09:00:00
# Datos de t-1 días antes: 2022-11-09 09:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-11-09 09:00:00
# Datos de t-1 días antes: 2022-11-08 09:00:00 [15.6]
# Datos pasados final: [15.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-11-08 09:00:00
# Datos de t-1 días antes: 2022-11-07 09:00:00 [16.4]
# Datos pasados final: [16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-11-07 09:00:00
# Datos de t-1 días antes: 2022-11-06 09:00:00 [17.1]
# Datos pasados final: [17.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-06 09:00:00
# Datos de t-1 días antes: 2022-11-05 09:00:00 [17.9]
# Datos pasados final: [17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-05 09:00:00
# Datos de t-1 días antes: 2022-11-04 09:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-11-04 09:00:00
# Datos de t-1 días antes: 2022-11-03 09:00:00 [15.4]
# Datos pasados final: [15.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.4): 2022-11-03 09:00:00
# Datos de t-1 días antes: 2022-11-02 09:00:00 [14.6]
# Datos pasados final: [14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-11-02 09:00:00
# Datos de t-1 días antes: 2022-11-01 09:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-11-01 09:00:00
# Datos de t-1 días antes: 2022-10-31 09:00:00 [17.9]
# Datos pasados final: [17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-10-31 09:00:00
# Datos de t-1 días antes: 2022-10-30 09:00:00 [19.7]
# Datos pasados final: [19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-10-30 09:00:00
# Datos de t-1 días antes: 2022-10-29 09:00:00 [15.0]
# Datos pasados final: [15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-29 09:00:00
# Datos de t-1 días antes: 2022-10-28 09:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-28 09:00:00
# Datos de t-1 días antes: 2022-10-27 09:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-10-27 09:00:00
# Datos de t-1 días antes: 2022-10-26 09:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-10-26 09:00:00
# Datos de t-1 días antes: 2022-10-25 09:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-10-25 09:00:00
# Datos de t-1 días antes: 2022-10-24 09:00:00 [17.4]
# Datos pasados final: [17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-10-24 09:00:00
# Datos de t-1 días antes: 2022-10-23 09:00:00 [17.4]
# Datos pasados final: [17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-10-23 09:00:00
# Datos de t-1 días antes: 2022-10-22 09:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-22 09:00:00
# Datos de t-1 días antes: 2022-10-21 09:00:00 [14.1]
# Datos pasados final: [14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-10-21 09:00:00
# Datos de t-1 días antes: 2022-10-20 09:00:00 [11.1]
# Datos pasados final: [11.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 11.1): 2022-10-20 09:00:00
# Datos de t-1 días antes: 2022-10-19 09:00:00 [13.0]
# Datos pasados final: [13.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.0): 2022-10-19 09:00:00
# Datos de t-1 días antes: 2022-10-18 09:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-10-18 09:00:00
# Datos de t-1 días antes: 2022-10-17 09:00:00 [16.9]
# Datos pasados final: [16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-10-17 09:00:00
# Datos de t-1 días antes: 2022-10-16 09:00:00 [15.8]
# Datos pasados final: [15.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.8): 2022-10-16 09:00:00
# Datos de t-1 días antes: 2022-10-15 09:00:00 [15.8]
# Datos pasados final: [15.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.8): 2022-10-15 09:00:00
# Datos de t-1 días antes: 2022-10-14 09:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-10-14 09:00:00
# Datos de t-1 días antes: 2022-10-13 09:00:00 [16.0]
# Datos pasados final: [16.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.0): 2022-10-13 09:00:00
# Datos de t-1 días antes: 2022-10-12 09:00:00 [16.0]
# Datos pasados final: [16.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.0): 2022-10-12 09:00:00
# Datos de t-1 días antes: 2022-10-11 09:00:00 [13.4]
# Datos pasados final: [13.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.4): 2022-10-11 09:00:00
# Datos de t-1 días antes: 2022-10-10 09:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-10-10 09:00:00
# Datos de t-1 días antes: 2022-10-09 09:00:00 [13.6]
# Datos pasados final: [13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-09 09:00:00
# Datos de t-1 días antes: 2022-10-08 09:00:00 [13.9]
# Datos pasados final: [13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-10-08 09:00:00
# Datos de t-1 días antes: 2022-10-07 09:00:00 [13.9]
# Datos pasados final: [13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-10-07 09:00:00
# Datos de t-1 días antes: 2022-10-06 09:00:00 [14.1]
# Datos pasados final: [14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-10-06 09:00:00
# Datos de t-1 días antes: 2022-10-05 09:00:00 [14.3]
# Datos pasados final: [14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-05 09:00:00
# Datos de t-1 días antes: 2022-10-04 09:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-10-04 09:00:00
# Datos de t-1 días antes: 2022-10-03 09:00:00 [12.5]
# Datos pasados final: [12.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 12.5): 2022-10-03 09:00:00
# Datos de t-1 días antes: 2022-10-02 09:00:00 [13.7]
# Datos pasados final: [13.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.7): 2022-10-02 09:00:00
# Datos de t-1 días antes: 2022-10-01 09:00:00 [12.2]
# Datos pasados final: [12.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 12.2): 2022-10-01 09:00:00
# Datos de t-1 días antes: 2022-09-30 09:00:00 [11.7]
# Datos pasados final: [11.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 11.7): 2022-09-30 09:00:00
# Datos de t-1 días antes: 2022-09-29 09:00:00 [11.7]
# Datos pasados final: [11.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 11.7): 2022-09-29 09:00:00
# Datos de t-1 días antes: 2022-09-28 09:00:00 [14.6]
# Datos pasados final: [14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-09-28 09:00:00
# Datos de t-1 días antes: 2022-09-27 09:00:00 [13.4]
# Datos pasados final: [13.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.4): 2022-09-27 09:00:00
# Datos de t-1 días antes: 2022-09-26 09:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-09-26 09:00:00
# Datos de t-1 días antes: 2022-09-25 09:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-25 09:00:00
# Datos de t-1 días antes: 2022-09-24 09:00:00 [15.8]
# Datos pasados final: [15.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.8): 2022-09-24 09:00:00
# Datos de t-1 días antes: 2022-09-23 09:00:00 [14.7]
# Datos pasados final: [14.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.7): 2022-09-23 09:00:00
# Datos de t-1 días antes: 2022-09-22 09:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-09-22 09:00:00
# Datos de t-1 días antes: 2022-09-21 09:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-21 09:00:00
# Datos de t-1 días antes: 2022-09-20 09:00:00 [14.6]
# Datos pasados final: [14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-09-20 09:00:00
# Datos de t-1 días antes: 2022-09-19 09:00:00 [14.7]
# Datos pasados final: [14.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.7): 2022-09-19 09:00:00
# Datos de t-1 días antes: 2022-09-18 09:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-09-18 09:00:00
# Datos de t-1 días antes: 2022-09-17 09:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-17 09:00:00
# Datos de t-1 días antes: 2022-09-16 09:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-16 09:00:00
# Datos de t-1 días antes: 2022-09-15 09:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-09-15 09:00:00
# Datos de t-1 días antes: 2022-09-14 09:00:00 [14.4]
# Datos pasados final: [14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-09-14 09:00:00
# Datos de t-1 días antes: 2022-09-13 09:00:00 [15.4]
# Datos pasados final: [15.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.4): 2022-09-13 09:00:00
# Datos de t-1 días antes: 2022-09-12 09:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-09-12 09:00:00
# Datos de t-1 días antes: 2022-09-11 09:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-09-11 09:00:00
# Datos de t-1 días antes: 2022-09-10 09:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-09-10 09:00:00
# Datos de t-1 días antes: 2022-09-09 09:00:00 [16.4]
# Datos pasados final: [16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-09 09:00:00
# Datos de t-1 días antes: 2022-09-08 09:00:00 [14.3]
# Datos pasados final: [14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-09-08 09:00:00
# Datos de t-1 días antes: 2022-09-07 09:00:00 [14.6]
# Datos pasados final: [14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-09-07 09:00:00
# Datos de t-1 días antes: 2022-09-06 09:00:00 [15.9]
# Datos pasados final: [15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-09-06 09:00:00
# Datos de t-1 días antes: 2022-09-05 09:00:00 [17.3]
# Datos pasados final: [17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-09-05 09:00:00
# Datos de t-1 días antes: 2022-09-04 09:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-09-04 09:00:00
# Datos de t-1 días antes: 2022-09-03 09:00:00 [15.6]
# Datos pasados final: [15.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-09-03 09:00:00
# Datos de t-1 días antes: 2022-09-02 09:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-02 09:00:00
# Datos de t-1 días antes: 2022-09-01 09:00:00 [15.9]
# Datos pasados final: [15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-09-01 09:00:00
# Datos de t-1 días antes: 2022-08-31 09:00:00 [17.2]
# Datos pasados final: [17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-08-31 09:00:00
# Datos de t-1 días antes: 2022-08-30 09:00:00 [17.6]
# Datos pasados final: [17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-08-30 09:00:00
# Datos de t-1 días antes: 2022-08-29 09:00:00 [15.3]
# Datos pasados final: [15.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.3): 2022-08-29 09:00:00
# Datos de t-1 días antes: 2022-08-28 09:00:00 [15.2]
# Datos pasados final: [15.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.2): 2022-08-28 09:00:00
# Datos de t-1 días antes: 2022-08-27 09:00:00 [16.3]
# Datos pasados final: [16.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.3): 2022-08-27 09:00:00
# Datos de t-1 días antes: 2022-08-26 09:00:00 [16.3]
# Datos pasados final: [16.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.3): 2022-08-26 09:00:00
# Datos de t-1 días antes: 2022-08-25 09:00:00 [16.8]
# Datos pasados final: [16.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-08-25 09:00:00
# Datos de t-1 días antes: 2022-08-24 09:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-08-24 09:00:00
# Datos de t-1 días antes: 2022-08-23 09:00:00 [16.0]
# Datos pasados final: [16.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.0): 2022-08-23 09:00:00
# Datos de t-1 días antes: 2022-08-22 09:00:00 [15.2]
# Datos pasados final: [15.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.2): 2022-08-22 09:00:00
# Datos de t-1 días antes: 2022-08-21 09:00:00 [15.8]
# Datos pasados final: [15.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.8): 2022-08-21 09:00:00
# Datos de t-1 días antes: 2022-08-20 09:00:00 [17.3]
# Datos pasados final: [17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-08-20 09:00:00
# Datos de t-1 días antes: 2022-08-19 09:00:00 [16.1]
# Datos pasados final: [16.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.1): 2022-08-19 09:00:00
# Datos de t-1 días antes: 2022-08-18 09:00:00 [16.9]
# Datos pasados final: [16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-18 09:00:00
# Datos de t-1 días antes: 2022-08-17 09:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-08-17 09:00:00
# Datos de t-1 días antes: 2022-08-16 09:00:00 [14.1]
# Datos pasados final: [14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-08-16 09:00:00
# Datos de t-1 días antes: 2022-08-15 09:00:00 [17.1]
# Datos pasados final: [17.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-08-15 09:00:00
# Datos de t-1 días antes: 2022-08-14 09:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-14 09:00:00
# Datos de t-1 días antes: 2022-08-13 09:00:00 [16.8]
# Datos pasados final: [16.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-08-13 09:00:00
# Datos de t-1 días antes: 2022-08-12 09:00:00 [16.0]
# Datos pasados final: [16.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.0): 2022-08-12 09:00:00
# Datos de t-1 días antes: 2022-08-11 09:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-08-11 09:00:00
# Datos de t-1 días antes: 2022-08-10 09:00:00 [14.9]
# Datos pasados final: [14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-10 09:00:00
# Datos de t-1 días antes: 2022-08-09 09:00:00 [15.3]
# Datos pasados final: [15.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.3): 2022-08-09 09:00:00
# Datos de t-1 días antes: 2022-08-08 09:00:00 [15.4]
# Datos pasados final: [15.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.4): 2022-08-08 09:00:00
# Datos de t-1 días antes: 2022-08-07 09:00:00 [14.7]
# Datos pasados final: [14.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.7): 2022-08-07 09:00:00
# Datos de t-1 días antes: 2022-08-06 09:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-08-06 09:00:00
# Datos de t-1 días antes: 2022-08-05 09:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-05 09:00:00
# Datos de t-1 días antes: 2022-08-04 09:00:00 [18.1]
# Datos pasados final: [18.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.1): 2022-08-04 09:00:00
# Datos de t-1 días antes: 2022-08-03 09:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-08-03 09:00:00
# Datos de t-1 días antes: 2022-08-02 09:00:00 [15.4]
# Datos pasados final: [15.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.4): 2022-08-02 09:00:00
# Datos de t-1 días antes: 2022-08-01 09:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-08-01 09:00:00
# Datos de t-1 días antes: 2022-07-31 09:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-07-31 09:00:00
# Datos de t-1 días antes: 2022-07-30 09:00:00 [14.0]
# Datos pasados final: [14.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.0): 2022-07-30 09:00:00
# Datos de t-1 días antes: 2022-07-29 09:00:00 [15.4]
# Datos pasados final: [15.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.4): 2022-07-29 09:00:00
# Datos de t-1 días antes: 2022-07-28 09:00:00 [14.4]
# Datos pasados final: [14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-28 09:00:00
# Datos de t-1 días antes: 2022-07-27 09:00:00 [18.4]
# Datos pasados final: [18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-07-27 09:00:00
# Datos de t-1 días antes: 2022-07-26 09:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-26 09:00:00
# Datos de t-1 días antes: 2022-07-25 09:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-25 09:00:00
# Datos de t-1 días antes: 2022-07-24 09:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-07-24 09:00:00
# Datos de t-1 días antes: 2022-07-23 09:00:00 [16.9]
# Datos pasados final: [16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-07-23 09:00:00
# Datos de t-1 días antes: 2022-07-22 09:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-07-22 09:00:00
# Datos de t-1 días antes: 2022-07-21 09:00:00 [17.3]
# Datos pasados final: [17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-07-21 09:00:00
# Datos de t-1 días antes: 2022-07-20 09:00:00 [19.0]
# Datos pasados final: [19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-07-20 09:00:00
# Datos de t-1 días antes: 2022-07-19 09:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-07-19 09:00:00
# Datos de t-1 días antes: 2022-07-18 09:00:00 [14.2]
# Datos pasados final: [14.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.2): 2022-07-18 09:00:00
# Ya no hay más datos hacía atras, o la fecha 2022-07-17 09:00:00 no existe, se omite esta última instancia y termina la iteracion.

# %% [markdown]
# Se obtiene el primer lote de datos para visualizar:

# %%
# El número de muestras por lote varia dependiendo del tamaño del lote definido (BATCH_SIZE).
dl = dataTemp.train_dataloader()
x, y = next(iter(dl))

print(f'x shape={x.shape} dtype={x.dtype}')
print(f'y shape={y.shape} dtype={y.dtype}')
print(f"x = {x}")
print(f"y = {y}")
# Out:
# x shape=torch.Size([38, 1]) dtype=torch.float32
# y shape=torch.Size([38, 1]) dtype=torch.float32
# x = tensor([[0.5536],
#         [0.5536],
#         [0.8571],
#         [0.0000],
#         [0.9821],
#         [0.9464],
#         [0.8036],
#         [0.4286],
#         [0.7143],
#         [0.6429],
#         [0.7857],
#         [0.5536],
#         [1.0000],
#         [0.5536],
#         [0.7500],
#         [0.6071],
#         [0.6071],
#         [1.0000],
#         [0.5179],
#         [0.7143],
#         [0.7321],
#         [0.5179],
#         [0.3571],
#         [0.0000],
#         [0.6250],
#         [0.6964],
#         [0.7321],
#         [0.8750],
#         [0.8393],
#         [0.9107],
#         [0.3036],
#         [0.5179],
#         [0.4821],
#         [0.9643],
#         [0.5357],
#         [0.7679],
#         [0.6250],
#         [0.0893]])
# y = tensor([[14.7000],
#         [13.4000],
#         [15.1000],
#         [11.7000],
#         [15.9000],
#         [15.6000],
#         [16.9000],
#         [16.2000],
#         [16.5000],
#         [17.6000],
#         [17.3000],
#         [14.7000],
#         [15.8000],
#         [17.3000],
#         [14.6000],
#         [14.8000],
#         [14.8000],
#         [15.9000],
#         [14.3000],
#         [15.4000],
#         [15.1000],
#         [14.5000],
#         [12.5000],
#         [12.2000],
#         [16.0000],
#         [14.8000],
#         [15.2000],
#         [17.1000],
#         [15.7000],
#         [16.6000],
#         [14.6000],
#         [11.7000],
#         [15.7000],
#         [14.1000],
#         [15.8000],
#         [15.5000],
#         [15.3000],
#         [13.7000]])

# %%
# El número de muestras por lote varia dependiendo del tamaño del lote definido (BATCH_SIZE).
dl = dataTemp.val_dataloader()
x, y = next(iter(dl))

print(f'x shape={x.shape} dtype={x.dtype}')
print(f'y shape={y.shape} dtype={y.dtype}')
print(f"x = {x}")
print(f"y = {y}")
# Out:
# x shape=torch.Size([13, 1]) dtype=torch.float32
# y shape=torch.Size([13, 1]) dtype=torch.float32
# x = tensor([[0.5536],
#         [1.0536],
#         [0.4643],
#         [0.7143],
#         [0.9107],
#         [0.8214],
#         [0.6786],
#         [0.9286],
#         [0.5357],
#         [0.6607],
#         [0.7500],
#         [0.5000],
#         [0.8214]])
# y = tensor([[15.7000],
#         [17.2000],
#         [16.4000],
#         [14.8000],
#         [16.3000],
#         [16.3000],
#         [16.8000],
#         [16.1000],
#         [14.6000],
#         [14.4000],
#         [17.0000],
#         [14.8000],
#         [15.2000]])

# %%
dataTemp.Y_val_horaLocal
# Out:
#             Hora Local
# 60 2022-09-12 09:00:00
# 72 2022-08-31 09:00:00
# 63 2022-09-09 09:00:00
# 61 2022-09-11 09:00:00
# 77 2022-08-26 09:00:00
# 76 2022-08-27 09:00:00
# 78 2022-08-25 09:00:00
# 84 2022-08-19 09:00:00
# 52 2022-09-20 09:00:00
# 58 2022-09-14 09:00:00
# 70 2022-09-02 09:00:00
# 50 2022-09-22 09:00:00
# 75 2022-08-28 09:00:00

# %% [markdown]
# ### Definición del modelo

# %%
class LinReg(pl.LightningModule):

  def __init__(self, numEntradas, neuronasOcultas=[100,100], lr=0.000001):
    # Se llama al inicializador de la clase padre
    super(LinReg, self).__init__()

    # Se define el numero de entradas y salidas del modelo
    self.numEntradas = numEntradas
    self.numSalidas = 1
    self.neuronasOcultas = neuronasOcultas

    # Se define la tasa de aprendizaje
    self.lr = lr

    # Se define la arquitectura del modelo
    self.fc1 = nn.Linear(self.numEntradas, self.neuronasOcultas[0])
    self.fc2 = nn.Linear(self.neuronasOcultas[0], self.neuronasOcultas[1])
    self.out = nn.Linear(self.neuronasOcultas[1], self.numSalidas)
          
    # Se define la función de pérdida para entrenamiento
    self.loss = nn.MSELoss()
    
  def forward(self, x):
    # Se define la función forward (hacia adelante) del modelo
    if(type(x) is list):
      x = x[0]

    x = self.fc1(x)
    x = F.leaky_relu(x)
    x = self.fc2(x)
    x = F.leaky_relu(x)
    x = self.out(x)
    return x

  def configure_optimizers(self):
    # Se define como optimizador el descenso por gradiente estocástico (con momento)
    return torch.optim.Adam(self.parameters(), lr = self.lr)

  # Se definen los pasos de entrenamiento del modelo
  def training_step(self, train_batch, batch_idx):
    # Se obtienen los datos del lote
    x, y = train_batch
    # Se hace inferencia para obtener los logits
    logits = self.forward(x)
    # Se calcula la pérdida con los datos de entrenamiento
    loss = self.loss(logits, y)
    MAE_obj = MeanAbsoluteError()
    MAE_loss = MAE_obj(logits, y)#nn.L1Loss(logits, y)#(y - logits).abs().mean()
    RMSE_loss = torch.sqrt(loss)#(y - logits).abs().mean()

    output={
      "loss": loss,
      "MAE_loss": MAE_loss,
      "RMSE_loss": RMSE_loss
    }

    # Retorna la pérdida del lote
    return output

  # Se definen los pasos de validación del modelo
  def validation_step(self, valid_batch, batch_idx):
    # Se obtienen los datos del lote
    x, y = valid_batch
    # Se hace inferencia para obtener los logits
    logits = self.forward(x)
    #Se calcula la pérdida con los datos de validación
    loss = self.loss(logits, y)
    MAE_obj = MeanAbsoluteError()
    MAE_loss = MAE_obj(logits, y)#nn.L1Loss(logits, y)#(y - logits).abs().mean()
    RMSE_loss = torch.sqrt(loss)#(y - logits).abs().mean()

    output={
      "loss": loss,
      "MAE_loss": MAE_loss,
      "RMSE_loss": RMSE_loss
    }

    # Retorna la pérdida del lote
    return output

  # Esta función se llama cuando cada época de entrenamiento termina
  def training_epoch_end(self, outputs):

    # Se calcula el promedio de todos los lotes en la época
    avg_loss_trn = torch.stack([x['loss'] for x in outputs]).mean()
    avg_MAE_loss_trn = torch.stack([x['MAE_loss'] for x in outputs]).mean()
    avg_RMSE_loss_trn = torch.stack([x['RMSE_loss'] for x in outputs]).mean()

    # Se manda graficar a TensorBoard
    self.logger.experiment.add_scalar("Pérdida/MSE Entrenamiento",
                                      avg_loss_trn,
                                      self.current_epoch)
    self.logger.experiment.add_scalar("Pérdida/MAE Entrenamiento",
                                      avg_MAE_loss_trn,
                                      self.current_epoch)
    self.logger.experiment.add_scalar("Pérdida/RMSE Entrenamiento",
                                      avg_RMSE_loss_trn,
                                      self.current_epoch)
    
  # Esta función se llama cuando cada época de validación termina
  def validation_epoch_end(self, outputs):

    # Se calcula el promedio de todos los lotes en la época
    avg_loss_val = torch.stack([x['loss'] for x in outputs]).mean()
    avg_MAE_loss_trn = torch.stack([x['MAE_loss'] for x in outputs]).mean()
    avg_RMSE_loss_trn = torch.stack([x['RMSE_loss'] for x in outputs]).mean()

    # Se manda graficar a TensorBoard
    self.logger.experiment.add_scalar("Pérdida/MSE Validación",
                                      avg_loss_val,
                                      self.current_epoch)
    self.logger.experiment.add_scalar("Pérdida/MAE Validación",
                                      avg_MAE_loss_trn,
                                      self.current_epoch)
    self.logger.experiment.add_scalar("Pérdida/RMSE Validación",
                                      avg_RMSE_loss_trn,
                                      self.current_epoch)

# %% [markdown]
# ### Entrenamiento del modelo
#
# https://pytorch-lightning.readthedocs.io/en/stable/common/trainer.html

# %% [markdown]
# #### Experimento con variables meteorológicas

# %% [markdown]
# ##### 9PM

# %% [markdown]
# ###### pasosPasado=1, pasosFuturo=1, sin Dirección del viento ni Dirección de la ráfaga

# %%
seed_everything(SEED, workers=True)

# Se crea el conjunto de datos
dataENCB90_exp1 = Data_ENCB_90('21:00:00', pasosPasado=1, pasosFuturo=1, excluirColumnasX=["Direcci�n del Viento (grados)","Direcci�n de r�faga (grados)","Rapidez de viento (km/h)","Rapidez de r�faga (km/h)","Humedad relativa (%)","Presi�n Atmosf�rica (hpa)","Precipitaci�n (mm)","Radiaci�n Solar (W/m�)"])
dataENCB90_exp1.prepare_data()
# Se crea el modelo
modelLinReg_exp1 = LinReg(dataENCB90_exp1.X.shape[1], neuronasOcultas=[24*2, 12*2], lr=0.1)

# Se inicializan los registros para el entrenamiento y la prueba
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
logger = TensorBoardLogger(save_dir = logdir, name="ENCB_90_exp1")

# Comienza el entrenamiento
trainer = pl.Trainer(max_epochs=50, logger=logger, log_every_n_steps=1, deterministic=True, accelerator="auto")
trainer.fit(modelLinReg_exp1, dataENCB90_exp1)
# Out:
# INFO:lightning_lite.utilities.seed:Global seed set to 99
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-11 21:00:00
# Datos de t-1 días antes: 2022-11-10 21:00:00 [17.9]
# Datos pasados final: [17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-10 21:00:00
# Datos de t-1 días antes: 2022-11-09 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-11-09 21:00:00
# Datos de t-1 días antes: 2022-11-08 21:00:00 [14.9]
# Datos pasados final: [14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-11-08 21:00:00
# Datos de t-1 días antes: 2022-11-07 21:00:00 [16.8]
# Datos pasados final: [16.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-11-07 21:00:00
# Datos de t-1 días antes: 2022-11-06 21:00:00 [18.6]
# Datos pasados final: [18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-06 21:00:00
# Datos de t-1 días antes: 2022-11-05 21:00:00 [18.8]
# Datos pasados final: [18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-11-05 21:00:00
# Datos de t-1 días antes: 2022-11-04 21:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-11-04 21:00:00
# Datos de t-1 días antes: 2022-11-03 21:00:00 [19.3]
# Datos pasados final: [19.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.3): 2022-11-03 21:00:00
# Datos de t-1 días antes: 2022-11-02 21:00:00 [17.1]
# Datos pasados final: [17.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-02 21:00:00
# Datos de t-1 días antes: 2022-11-01 21:00:00 [18.4]
# Datos pasados final: [18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-11-01 21:00:00
# Datos de t-1 días antes: 2022-10-31 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-10-31 21:00:00
# Datos de t-1 días antes: 2022-10-30 21:00:00 [19.0]
# Datos pasados final: [19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-10-30 21:00:00
# Datos de t-1 días antes: 2022-10-29 21:00:00 [20.1]
# Datos pasados final: [20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-10-29 21:00:00
# Datos de t-1 días antes: 2022-10-28 21:00:00 [19.5]
# Datos pasados final: [19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-10-28 21:00:00
# Datos de t-1 días antes: 2022-10-27 21:00:00 [19.9]
# Datos pasados final: [19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-10-27 21:00:00
# Datos de t-1 días antes: 2022-10-26 21:00:00 [21.1]
# Datos pasados final: [21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-26 21:00:00
# Datos de t-1 días antes: 2022-10-25 21:00:00 [21.1]
# Datos pasados final: [21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-25 21:00:00
# Datos de t-1 días antes: 2022-10-24 21:00:00 [21.9]
# Datos pasados final: [21.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.9): 2022-10-24 21:00:00
# Datos de t-1 días antes: 2022-10-23 21:00:00 [20.6]
# Datos pasados final: [20.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.6): 2022-10-23 21:00:00
# Datos de t-1 días antes: 2022-10-22 21:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-10-22 21:00:00
# Datos de t-1 días antes: 2022-10-21 21:00:00 [15.9]
# Datos pasados final: [15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-10-21 21:00:00
# Datos de t-1 días antes: 2022-10-20 21:00:00 [18.4]
# Datos pasados final: [18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-10-20 21:00:00
# Datos de t-1 días antes: 2022-10-19 21:00:00 [13.5]
# Datos pasados final: [13.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.5): 2022-10-19 21:00:00
# Datos de t-1 días antes: 2022-10-18 21:00:00 [15.0]
# Datos pasados final: [15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-18 21:00:00
# Datos de t-1 días antes: 2022-10-17 21:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-17 21:00:00
# Datos de t-1 días antes: 2022-10-16 21:00:00 [21.2]
# Datos pasados final: [21.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.2): 2022-10-16 21:00:00
# Datos de t-1 días antes: 2022-10-15 21:00:00 [20.3]
# Datos pasados final: [20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-15 21:00:00
# Datos de t-1 días antes: 2022-10-14 21:00:00 [19.2]
# Datos pasados final: [19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-10-14 21:00:00
# Datos de t-1 días antes: 2022-10-13 21:00:00 [19.1]
# Datos pasados final: [19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-10-13 21:00:00
# Datos de t-1 días antes: 2022-10-12 21:00:00 [20.3]
# Datos pasados final: [20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-12 21:00:00
# Datos de t-1 días antes: 2022-10-11 21:00:00 [17.3]
# Datos pasados final: [17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-10-11 21:00:00
# Datos de t-1 días antes: 2022-10-10 21:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-10-10 21:00:00
# Datos de t-1 días antes: 2022-10-09 21:00:00 [14.3]
# Datos pasados final: [14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-09 21:00:00
# Datos de t-1 días antes: 2022-10-08 21:00:00 [14.6]
# Datos pasados final: [14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-10-08 21:00:00
# Datos de t-1 días antes: 2022-10-07 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-07 21:00:00
# Datos de t-1 días antes: 2022-10-06 21:00:00 [13.6]
# Datos pasados final: [13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-06 21:00:00
# Datos de t-1 días antes: 2022-10-05 21:00:00 [14.4]
# Datos pasados final: [14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-10-05 21:00:00
# Datos de t-1 días antes: 2022-10-04 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-04 21:00:00
# Datos de t-1 días antes: 2022-10-03 21:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-03 21:00:00
# Datos de t-1 días antes: 2022-10-02 21:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-02 21:00:00
# Datos de t-1 días antes: 2022-10-01 21:00:00 [17.8]
# Datos pasados final: [17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-10-01 21:00:00
# Datos de t-1 días antes: 2022-09-30 21:00:00 [16.4]
# Datos pasados final: [16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-30 21:00:00
# Datos de t-1 días antes: 2022-09-29 21:00:00 [14.1]
# Datos pasados final: [14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-09-29 21:00:00
# Datos de t-1 días antes: 2022-09-28 21:00:00 [13.9]
# Datos pasados final: [13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-09-28 21:00:00
# Datos de t-1 días antes: 2022-09-27 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-27 21:00:00
# Datos de t-1 días antes: 2022-09-26 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-26 21:00:00
# Datos de t-1 días antes: 2022-09-25 21:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-25 21:00:00
# Datos de t-1 días antes: 2022-09-24 21:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-24 21:00:00
# Datos de t-1 días antes: 2022-09-23 21:00:00 [17.9]
# Datos pasados final: [17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-09-23 21:00:00
# Datos de t-1 días antes: 2022-09-22 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-22 21:00:00
# Datos de t-1 días antes: 2022-09-21 21:00:00 [18.0]
# Datos pasados final: [18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-21 21:00:00
# Datos de t-1 días antes: 2022-09-20 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-09-20 21:00:00
# Datos de t-1 días antes: 2022-09-19 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-19 21:00:00
# Datos de t-1 días antes: 2022-09-18 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-18 21:00:00
# Datos de t-1 días antes: 2022-09-17 21:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-09-17 21:00:00
# Datos de t-1 días antes: 2022-09-16 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-16 21:00:00
# Datos de t-1 días antes: 2022-09-15 21:00:00 [17.6]
# Datos pasados final: [17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-09-15 21:00:00
# Datos de t-1 días antes: 2022-09-14 21:00:00 [19.0]
# Datos pasados final: [19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-09-14 21:00:00
# Datos de t-1 días antes: 2022-09-13 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-13 21:00:00
# Datos de t-1 días antes: 2022-09-12 21:00:00 [18.5]
# Datos pasados final: [18.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.5): 2022-09-12 21:00:00
# Datos de t-1 días antes: 2022-09-11 21:00:00 [18.8]
# Datos pasados final: [18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-09-11 21:00:00
# Datos de t-1 días antes: 2022-09-10 21:00:00 [20.2]
# Datos pasados final: [20.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.2): 2022-09-10 21:00:00
# Datos de t-1 días antes: 2022-09-09 21:00:00 [20.3]
# Datos pasados final: [20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-09-09 21:00:00
# Datos de t-1 días antes: 2022-09-08 21:00:00 [17.8]
# Datos pasados final: [17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-09-08 21:00:00
# Datos de t-1 días antes: 2022-09-07 21:00:00 [17.2]
# Datos pasados final: [17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-09-07 21:00:00
# Datos de t-1 días antes: 2022-09-06 21:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-06 21:00:00
# Datos de t-1 días antes: 2022-09-05 21:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-09-05 21:00:00
# Datos de t-1 días antes: 2022-09-04 21:00:00 [18.0]
# Datos pasados final: [18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-04 21:00:00
# Datos de t-1 días antes: 2022-09-03 21:00:00 [18.0]
# Datos pasados final: [18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-03 21:00:00
# Datos de t-1 días antes: 2022-09-02 21:00:00 [19.1]
# Datos pasados final: [19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-09-02 21:00:00
# Datos de t-1 días antes: 2022-09-01 21:00:00 [20.4]
# Datos pasados final: [20.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.4): 2022-09-01 21:00:00
# Datos de t-1 días antes: 2022-08-31 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-31 21:00:00
# Datos de t-1 días antes: 2022-08-30 21:00:00 [19.1]
# Datos pasados final: [19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-08-30 21:00:00
# Datos de t-1 días antes: 2022-08-29 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-29 21:00:00
# Datos de t-1 días antes: 2022-08-28 21:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-28 21:00:00
# Datos de t-1 días antes: 2022-08-27 21:00:00 [20.1]
# Datos pasados final: [20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-08-27 21:00:00
# Datos de t-1 días antes: 2022-08-26 21:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-08-26 21:00:00
# Datos de t-1 días antes: 2022-08-25 21:00:00 [20.1]
# Datos pasados final: [20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-08-25 21:00:00
# Datos de t-1 días antes: 2022-08-24 21:00:00 [19.6]
# Datos pasados final: [19.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.6): 2022-08-24 21:00:00
# Datos de t-1 días antes: 2022-08-23 21:00:00 [20.5]
# Datos pasados final: [20.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.5): 2022-08-23 21:00:00
# Datos de t-1 días antes: 2022-08-22 21:00:00 [19.2]
# Datos pasados final: [19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-08-22 21:00:00
# Datos de t-1 días antes: 2022-08-21 21:00:00 [19.4]
# Datos pasados final: [19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-08-21 21:00:00
# Datos de t-1 días antes: 2022-08-20 21:00:00 [17.4]
# Datos pasados final: [17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-20 21:00:00
# Datos de t-1 días antes: 2022-08-19 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-19 21:00:00
# Datos de t-1 días antes: 2022-08-18 21:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-18 21:00:00
# Datos de t-1 días antes: 2022-08-17 21:00:00 [19.8]
# Datos pasados final: [19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-17 21:00:00
# Datos de t-1 días antes: 2022-08-16 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-16 21:00:00
# Datos de t-1 días antes: 2022-08-15 21:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-15 21:00:00
# Datos de t-1 días antes: 2022-08-14 21:00:00 [19.5]
# Datos pasados final: [19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-08-14 21:00:00
# Datos de t-1 días antes: 2022-08-13 21:00:00 [16.9]
# Datos pasados final: [16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-13 21:00:00
# Datos de t-1 días antes: 2022-08-12 21:00:00 [15.6]
# Datos pasados final: [15.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos pasados final: [20.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos pasados final: [19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos pasados final: [14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos pasados final: [18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos pasados final: [19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-25 21:00:00
# Datos de t-1 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-07-24 21:00:00
# Datos de t-1 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-07-23 21:00:00
# Datos de t-1 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-07-22 21:00:00
# Datos de t-1 días antes: 2022-07-21 21:00:00 [23.3]
# Datos pasados final: [23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 23.3): 2022-07-21 21:00:00
# Datos de t-1 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 24.3): 2022-07-20 21:00:00
# Datos de t-1 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-07-19 21:00:00
# Datos de t-1 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-07-18 21:00:00
# Datos de t-1 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-17 21:00:00
# Ya no hay más datos hacía atras, o la fecha 2022-07-16 21:00:00 no existe, se omite esta última instancia y termina la iteracion.
# /usr/local/lib/python3.7/dist-packages/lightning_lite/accelerators/cuda.py:159: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-11 21:00:00
# Datos de t-1 días antes: 2022-11-10 21:00:00 [17.9]
# Datos pasados final: [17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-10 21:00:00
# Datos de t-1 días antes: 2022-11-09 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-11-09 21:00:00
# Datos de t-1 días antes: 2022-11-08 21:00:00 [14.9]
# Datos pasados final: [14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-11-08 21:00:00
# Datos de t-1 días antes: 2022-11-07 21:00:00 [16.8]
# Datos pasados final: [16.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-11-07 21:00:00
# Datos de t-1 días antes: 2022-11-06 21:00:00 [18.6]
# Datos pasados final: [18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-06 21:00:00
# Datos de t-1 días antes: 2022-11-05 21:00:00 [18.8]
# Datos pasados final: [18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-11-05 21:00:00
# Datos de t-1 días antes: 2022-11-04 21:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-11-04 21:00:00
# Datos de t-1 días antes: 2022-11-03 21:00:00 [19.3]
# Datos pasados final: [19.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.3): 2022-11-03 21:00:00
# Datos de t-1 días antes: 2022-11-02 21:00:00 [17.1]
# Datos pasados final: [17.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-02 21:00:00
# Datos de t-1 días antes: 2022-11-01 21:00:00 [18.4]
# Datos pasados final: [18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-11-01 21:00:00
# Datos de t-1 días antes: 2022-10-31 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-10-31 21:00:00
# Datos de t-1 días antes: 2022-10-30 21:00:00 [19.0]
# Datos pasados final: [19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-10-30 21:00:00
# Datos de t-1 días antes: 2022-10-29 21:00:00 [20.1]
# Datos pasados final: [20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-10-29 21:00:00
# Datos de t-1 días antes: 2022-10-28 21:00:00 [19.5]
# Datos pasados final: [19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-10-28 21:00:00
# Datos de t-1 días antes: 2022-10-27 21:00:00 [19.9]
# Datos pasados final: [19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-10-27 21:00:00
# Datos de t-1 días antes: 2022-10-26 21:00:00 [21.1]
# Datos pasados final: [21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-26 21:00:00
# Datos de t-1 días antes: 2022-10-25 21:00:00 [21.1]
# Datos pasados final: [21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-25 21:00:00
# Datos de t-1 días antes: 2022-10-24 21:00:00 [21.9]
# Datos pasados final: [21.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.9): 2022-10-24 21:00:00
# Datos de t-1 días antes: 2022-10-23 21:00:00 [20.6]
# Datos pasados final: [20.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.6): 2022-10-23 21:00:00
# Datos de t-1 días antes: 2022-10-22 21:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-10-22 21:00:00
# Datos de t-1 días antes: 2022-10-21 21:00:00 [15.9]
# Datos pasados final: [15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-10-21 21:00:00
# Datos de t-1 días antes: 2022-10-20 21:00:00 [18.4]
# Datos pasados final: [18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-10-20 21:00:00
# Datos de t-1 días antes: 2022-10-19 21:00:00 [13.5]
# Datos pasados final: [13.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.5): 2022-10-19 21:00:00
# Datos de t-1 días antes: 2022-10-18 21:00:00 [15.0]
# Datos pasados final: [15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-18 21:00:00
# Datos de t-1 días antes: 2022-10-17 21:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-17 21:00:00
# Datos de t-1 días antes: 2022-10-16 21:00:00 [21.2]
# Datos pasados final: [21.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.2): 2022-10-16 21:00:00
# Datos de t-1 días antes: 2022-10-15 21:00:00 [20.3]
# Datos pasados final: [20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-15 21:00:00
# Datos de t-1 días antes: 2022-10-14 21:00:00 [19.2]
# Datos pasados final: [19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-10-14 21:00:00
# Datos de t-1 días antes: 2022-10-13 21:00:00 [19.1]
# Datos pasados final: [19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-10-13 21:00:00
# Datos de t-1 días antes: 2022-10-12 21:00:00 [20.3]
# Datos pasados final: [20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-12 21:00:00
# Datos de t-1 días antes: 2022-10-11 21:00:00 [17.3]
# Datos pasados final: [17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-10-11 21:00:00
# Datos de t-1 días antes: 2022-10-10 21:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-10-10 21:00:00
# Datos de t-1 días antes: 2022-10-09 21:00:00 [14.3]
# Datos pasados final: [14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-09 21:00:00
# Datos de t-1 días antes: 2022-10-08 21:00:00 [14.6]
# Datos pasados final: [14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-10-08 21:00:00
# Datos de t-1 días antes: 2022-10-07 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-07 21:00:00
# Datos de t-1 días antes: 2022-10-06 21:00:00 [13.6]
# Datos pasados final: [13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-06 21:00:00
# Datos de t-1 días antes: 2022-10-05 21:00:00 [14.4]
# Datos pasados final: [14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-10-05 21:00:00
# Datos de t-1 días antes: 2022-10-04 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-04 21:00:00
# Datos de t-1 días antes: 2022-10-03 21:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-03 21:00:00
# Datos de t-1 días antes: 2022-10-02 21:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-02 21:00:00
# Datos de t-1 días antes: 2022-10-01 21:00:00 [17.8]
# Datos pasados final: [17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-10-01 21:00:00
# Datos de t-1 días antes: 2022-09-30 21:00:00 [16.4]
# Datos pasados final: [16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-30 21:00:00
# Datos de t-1 días antes: 2022-09-29 21:00:00 [14.1]
# Datos pasados final: [14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-09-29 21:00:00
# Datos de t-1 días antes: 2022-09-28 21:00:00 [13.9]
# Datos pasados final: [13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-09-28 21:00:00
# Datos de t-1 días antes: 2022-09-27 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-27 21:00:00
# Datos de t-1 días antes: 2022-09-26 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-26 21:00:00
# Datos de t-1 días antes: 2022-09-25 21:00:00 [17.0]
# Datos pasados final: [17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-25 21:00:00
# Datos de t-1 días antes: 2022-09-24 21:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-24 21:00:00
# Datos de t-1 días antes: 2022-09-23 21:00:00 [17.9]
# Datos pasados final: [17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-09-23 21:00:00
# Datos de t-1 días antes: 2022-09-22 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-22 21:00:00
# Datos de t-1 días antes: 2022-09-21 21:00:00 [18.0]
# Datos pasados final: [18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-21 21:00:00
# Datos de t-1 días antes: 2022-09-20 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-09-20 21:00:00
# Datos de t-1 días antes: 2022-09-19 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-19 21:00:00
# Datos de t-1 días antes: 2022-09-18 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-18 21:00:00
# Datos de t-1 días antes: 2022-09-17 21:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-09-17 21:00:00
# Datos de t-1 días antes: 2022-09-16 21:00:00 [16.2]
# Datos pasados final: [16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-16 21:00:00
# Datos de t-1 días antes: 2022-09-15 21:00:00 [17.6]
# Datos pasados final: [17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-09-15 21:00:00
# Datos de t-1 días antes: 2022-09-14 21:00:00 [19.0]
# Datos pasados final: [19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-09-14 21:00:00
# Datos de t-1 días antes: 2022-09-13 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-13 21:00:00
# Datos de t-1 días antes: 2022-09-12 21:00:00 [18.5]
# Datos pasados final: [18.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.5): 2022-09-12 21:00:00
# Datos de t-1 días antes: 2022-09-11 21:00:00 [18.8]
# Datos pasados final: [18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-09-11 21:00:00
# Datos de t-1 días antes: 2022-09-10 21:00:00 [20.2]
# Datos pasados final: [20.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.2): 2022-09-10 21:00:00
# Datos de t-1 días antes: 2022-09-09 21:00:00 [20.3]
# Datos pasados final: [20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-09-09 21:00:00
# Datos de t-1 días antes: 2022-09-08 21:00:00 [17.8]
# Datos pasados final: [17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-09-08 21:00:00
# Datos de t-1 días antes: 2022-09-07 21:00:00 [17.2]
# Datos pasados final: [17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-09-07 21:00:00
# Datos de t-1 días antes: 2022-09-06 21:00:00 [15.1]
# Datos pasados final: [15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-06 21:00:00
# Datos de t-1 días antes: 2022-09-05 21:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-09-05 21:00:00
# Datos de t-1 días antes: 2022-09-04 21:00:00 [18.0]
# Datos pasados final: [18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-04 21:00:00
# Datos de t-1 días antes: 2022-09-03 21:00:00 [18.0]
# Datos pasados final: [18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-03 21:00:00
# Datos de t-1 días antes: 2022-09-02 21:00:00 [19.1]
# Datos pasados final: [19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-09-02 21:00:00
# Datos de t-1 días antes: 2022-09-01 21:00:00 [20.4]
# Datos pasados final: [20.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.4): 2022-09-01 21:00:00
# Datos de t-1 días antes: 2022-08-31 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-31 21:00:00
# Datos de t-1 días antes: 2022-08-30 21:00:00 [19.1]
# Datos pasados final: [19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-08-30 21:00:00
# Datos de t-1 días antes: 2022-08-29 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-29 21:00:00
# Datos de t-1 días antes: 2022-08-28 21:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-28 21:00:00
# Datos de t-1 días antes: 2022-08-27 21:00:00 [20.1]
# Datos pasados final: [20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-08-27 21:00:00
# Datos de t-1 días antes: 2022-08-26 21:00:00 [15.7]
# Datos pasados final: [15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-08-26 21:00:00
# Datos de t-1 días antes: 2022-08-25 21:00:00 [20.1]
# Datos pasados final: [20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-08-25 21:00:00
# Datos de t-1 días antes: 2022-08-24 21:00:00 [19.6]
# Datos pasados final: [19.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.6): 2022-08-24 21:00:00
# Datos de t-1 días antes: 2022-08-23 21:00:00 [20.5]
# Datos pasados final: [20.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.5): 2022-08-23 21:00:00
# Datos de t-1 días antes: 2022-08-22 21:00:00 [19.2]
# Datos pasados final: [19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-08-22 21:00:00
# Datos de t-1 días antes: 2022-08-21 21:00:00 [19.4]
# Datos pasados final: [19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-08-21 21:00:00
# Datos de t-1 días antes: 2022-08-20 21:00:00 [17.4]
# Datos pasados final: [17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-20 21:00:00
# Datos de t-1 días antes: 2022-08-19 21:00:00 [18.7]
# Datos pasados final: [18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-19 21:00:00
# Datos de t-1 días antes: 2022-08-18 21:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-18 21:00:00
# Datos de t-1 días antes: 2022-08-17 21:00:00 [19.8]
# Datos pasados final: [19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-17 21:00:00
# Datos de t-1 días antes: 2022-08-16 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-16 21:00:00
# Datos de t-1 días antes: 2022-08-15 21:00:00 [14.8]
# Datos pasados final: [14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-15 21:00:00
# Datos de t-1 días antes: 2022-08-14 21:00:00 [19.5]
# Datos pasados final: [19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-08-14 21:00:00
# Datos de t-1 días antes: 2022-08-13 21:00:00 [16.9]
# Datos pasados final: [16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-13 21:00:00
# Datos de t-1 días antes: 2022-08-12 21:00:00 [15.6]
# Datos pasados final: [15.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos pasados final: [20.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos pasados final: [19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos pasados final: [14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos pasados final: [14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos pasados final: [18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos pasados final: [19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos pasados final: [18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-25 21:00:00
# Datos de t-1 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-07-24 21:00:00
# Datos de t-1 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-07-23 21:00:00
# Datos de t-1 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-07-22 21:00:00
# Datos de t-1 días antes: 2022-07-21 21:00:00 [23.3]
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: logs/20221128-054231/ENCB_90_exp1
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name | Type    | Params
# ---------------------------------
# 0 | fc1  | Linear  | 96
# 1 | fc2  | Linear  | 1.2 K
# 2 | out  | Linear  | 25
# 3 | loss | MSELoss | 0
# ---------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# Datos pasados final: [23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 23.3): 2022-07-21 21:00:00
# Datos de t-1 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 24.3): 2022-07-20 21:00:00
# Datos de t-1 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-07-19 21:00:00
# Datos de t-1 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-07-18 21:00:00
# Datos de t-1 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-17 21:00:00
# Ya no hay más datos hacía atras, o la fecha 2022-07-16 21:00:00 no existe, se omite esta última instancia y termina la iteracion.
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=50` reached.

# %% [markdown]
# ###### pasosPasado=5, pasosFuturo=1, sin Dirección del viento ni Dirección de la ráfaga

# %%
seed_everything(SEED, workers=True)

# Se crea el conjunto de datos
dataENCB90_exp2 = Data_ENCB_90('21:00:00', pasosPasado=5, pasosFuturo=1, excluirColumnasX=["Direcci�n del Viento (grados)","Direcci�n de r�faga (grados)","Rapidez de viento (km/h)","Rapidez de r�faga (km/h)","Humedad relativa (%)","Presi�n Atmosf�rica (hpa)","Precipitaci�n (mm)","Radiaci�n Solar (W/m�)"])
dataENCB90_exp2.prepare_data()
# Se crea el modelo
modelLinReg_exp2 = LinReg(dataENCB90_exp2.X.shape[1], neuronasOcultas=[24*2, 12*2], lr=0.01)

# Se inicializan los registros para el entrenamiento y la prueba
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
logger = TensorBoardLogger(save_dir = logdir, name="ENCB_90_exp2")

# Comienza el entrenamiento
trainer = pl.Trainer(max_epochs=70, logger=logger, log_every_n_steps=1, deterministic=True, accelerator="auto")
trainer.fit(modelLinReg_exp2, dataENCB90_exp2)
# Out:
# INFO:lightning_lite.utilities.seed:Global seed set to 99
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-11 21:00:00
# Datos de t-1 días antes: 2022-11-10 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-5 días antes: 2022-11-06 21:00:00 [18.6]
# Datos pasados final: [17.9, 16.6, 14.9, 16.8, 18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-10 21:00:00
# Datos de t-1 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-4 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-11-05 21:00:00 [18.8]
# Datos pasados final: [16.6, 14.9, 16.8, 18.6, 18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-11-09 21:00:00
# Datos de t-1 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-3 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-11-04 21:00:00 [17.0]
# Datos pasados final: [14.9, 16.8, 18.6, 18.8, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-11-08 21:00:00
# Datos de t-1 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-2 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-11-03 21:00:00 [19.3]
# Datos pasados final: [16.8, 18.6, 18.8, 17.0, 19.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-11-07 21:00:00
# Datos de t-1 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-5 días antes: 2022-11-02 21:00:00 [17.1]
# Datos pasados final: [18.6, 18.8, 17.0, 19.3, 17.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-06 21:00:00
# Datos de t-1 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-4 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-5 días antes: 2022-11-01 21:00:00 [18.4]
# Datos pasados final: [18.8, 17.0, 19.3, 17.1, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-11-05 21:00:00
# Datos de t-1 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-3 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-4 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-31 21:00:00 [18.2]
# Datos pasados final: [17.0, 19.3, 17.1, 18.4, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-11-04 21:00:00
# Datos de t-1 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-2 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-3 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-10-30 21:00:00 [19.0]
# Datos pasados final: [19.3, 17.1, 18.4, 18.2, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.3): 2022-11-03 21:00:00
# Datos de t-1 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-2 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-10-29 21:00:00 [20.1]
# Datos pasados final: [17.1, 18.4, 18.2, 19.0, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-02 21:00:00
# Datos de t-1 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-5 días antes: 2022-10-28 21:00:00 [19.5]
# Datos pasados final: [18.4, 18.2, 19.0, 20.1, 19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-11-01 21:00:00
# Datos de t-1 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-4 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-5 días antes: 2022-10-27 21:00:00 [19.9]
# Datos pasados final: [18.2, 19.0, 20.1, 19.5, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-10-31 21:00:00
# Datos de t-1 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-3 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-4 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-10-26 21:00:00 [21.1]
# Datos pasados final: [19.0, 20.1, 19.5, 19.9, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-10-30 21:00:00
# Datos de t-1 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-2 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-25 21:00:00 [21.1]
# Datos pasados final: [20.1, 19.5, 19.9, 21.1, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-10-29 21:00:00
# Datos de t-1 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-24 21:00:00 [21.9]
# Datos pasados final: [19.5, 19.9, 21.1, 21.1, 21.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-10-28 21:00:00
# Datos de t-1 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-5 días antes: 2022-10-23 21:00:00 [20.6]
# Datos pasados final: [19.9, 21.1, 21.1, 21.9, 20.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-10-27 21:00:00
# Datos de t-1 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-4 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-5 días antes: 2022-10-22 21:00:00 [17.0]
# Datos pasados final: [21.1, 21.1, 21.9, 20.6, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-26 21:00:00
# Datos de t-1 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-3 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-4 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-10-21 21:00:00 [15.9]
# Datos pasados final: [21.1, 21.9, 20.6, 17.0, 15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-25 21:00:00
# Datos de t-1 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-2 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-3 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-5 días antes: 2022-10-20 21:00:00 [18.4]
# Datos pasados final: [21.9, 20.6, 17.0, 15.9, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.9): 2022-10-24 21:00:00
# Datos de t-1 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-2 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-4 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-19 21:00:00 [13.5]
# Datos pasados final: [20.6, 17.0, 15.9, 18.4, 13.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.6): 2022-10-23 21:00:00
# Datos de t-1 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-3 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-5 días antes: 2022-10-18 21:00:00 [15.0]
# Datos pasados final: [17.0, 15.9, 18.4, 13.5, 15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-10-22 21:00:00
# Datos de t-1 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-2 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-4 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-5 días antes: 2022-10-17 21:00:00 [15.1]
# Datos pasados final: [15.9, 18.4, 13.5, 15.0, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-10-21 21:00:00
# Datos de t-1 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-3 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-4 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-10-16 21:00:00 [21.2]
# Datos pasados final: [18.4, 13.5, 15.0, 15.1, 21.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-10-20 21:00:00
# Datos de t-1 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-2 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-3 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-5 días antes: 2022-10-15 21:00:00 [20.3]
# Datos pasados final: [13.5, 15.0, 15.1, 21.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.5): 2022-10-19 21:00:00
# Datos de t-1 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-2 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-4 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-14 21:00:00 [19.2]
# Datos pasados final: [15.0, 15.1, 21.2, 20.3, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-18 21:00:00
# Datos de t-1 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-3 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-10-13 21:00:00 [19.1]
# Datos pasados final: [15.1, 21.2, 20.3, 19.2, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-17 21:00:00
# Datos de t-1 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-2 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-10-12 21:00:00 [20.3]
# Datos pasados final: [21.2, 20.3, 19.2, 19.1, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.2): 2022-10-16 21:00:00
# Datos de t-1 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-4 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-11 21:00:00 [17.3]
# Datos pasados final: [20.3, 19.2, 19.1, 20.3, 17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-15 21:00:00
# Datos de t-1 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-3 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-5 días antes: 2022-10-10 21:00:00 [15.7]
# Datos pasados final: [19.2, 19.1, 20.3, 17.3, 15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-10-14 21:00:00
# Datos de t-1 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-2 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-4 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-5 días antes: 2022-10-09 21:00:00 [14.3]
# Datos pasados final: [19.1, 20.3, 17.3, 15.7, 14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-10-13 21:00:00
# Datos de t-1 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-3 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-4 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-5 días antes: 2022-10-08 21:00:00 [14.6]
# Datos pasados final: [20.3, 17.3, 15.7, 14.3, 14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-12 21:00:00
# Datos de t-1 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-2 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-3 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-4 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-5 días antes: 2022-10-07 21:00:00 [16.6]
# Datos pasados final: [17.3, 15.7, 14.3, 14.6, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-10-11 21:00:00
# Datos de t-1 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-2 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-3 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-4 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-06 21:00:00 [13.6]
# Datos pasados final: [15.7, 14.3, 14.6, 16.6, 13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-10-10 21:00:00
# Datos de t-1 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-2 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-3 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-5 días antes: 2022-10-05 21:00:00 [14.4]
# Datos pasados final: [14.3, 14.6, 16.6, 13.6, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-09 21:00:00
# Datos de t-1 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-2 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-4 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-10-04 21:00:00 [16.6]
# Datos pasados final: [14.6, 16.6, 13.6, 14.4, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-10-08 21:00:00
# Datos de t-1 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-3 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-03 21:00:00 [17.5]
# Datos pasados final: [16.6, 13.6, 14.4, 16.6, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-07 21:00:00
# Datos de t-1 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-2 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-02 21:00:00 [17.5]
# Datos pasados final: [13.6, 14.4, 16.6, 17.5, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-06 21:00:00
# Datos de t-1 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-01 21:00:00 [17.8]
# Datos pasados final: [14.4, 16.6, 17.5, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-10-05 21:00:00
# Datos de t-1 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-30 21:00:00 [16.4]
# Datos pasados final: [16.6, 17.5, 17.5, 17.8, 16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-04 21:00:00
# Datos de t-1 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-5 días antes: 2022-09-29 21:00:00 [14.1]
# Datos pasados final: [17.5, 17.5, 17.8, 16.4, 14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-03 21:00:00
# Datos de t-1 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-4 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-5 días antes: 2022-09-28 21:00:00 [13.9]
# Datos pasados final: [17.5, 17.8, 16.4, 14.1, 13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-02 21:00:00
# Datos de t-1 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-3 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-4 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-5 días antes: 2022-09-27 21:00:00 [16.2]
# Datos pasados final: [17.8, 16.4, 14.1, 13.9, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-10-01 21:00:00
# Datos de t-1 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-2 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-3 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-4 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-26 21:00:00 [16.2]
# Datos pasados final: [16.4, 14.1, 13.9, 16.2, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-30 21:00:00
# Datos de t-1 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-2 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-3 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-25 21:00:00 [17.0]
# Datos pasados final: [14.1, 13.9, 16.2, 16.2, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-09-29 21:00:00
# Datos de t-1 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-2 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-09-24 21:00:00 [14.5]
# Datos pasados final: [13.9, 16.2, 16.2, 17.0, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-09-28 21:00:00
# Datos de t-1 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-09-23 21:00:00 [17.9]
# Datos pasados final: [16.2, 16.2, 17.0, 14.5, 17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-27 21:00:00
# Datos de t-1 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-5 días antes: 2022-09-22 21:00:00 [18.2]
# Datos pasados final: [16.2, 17.0, 14.5, 17.9, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-26 21:00:00
# Datos de t-1 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-4 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-21 21:00:00 [18.0]
# Datos pasados final: [17.0, 14.5, 17.9, 18.2, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-25 21:00:00
# Datos de t-1 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-3 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-20 21:00:00 [18.7]
# Datos pasados final: [14.5, 17.9, 18.2, 18.0, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-24 21:00:00
# Datos de t-1 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-09-19 21:00:00 [16.5]
# Datos pasados final: [17.9, 18.2, 18.0, 18.7, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-09-23 21:00:00
# Datos de t-1 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-09-18 21:00:00 [16.2]
# Datos pasados final: [18.2, 18.0, 18.7, 16.5, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-22 21:00:00
# Datos de t-1 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-17 21:00:00 [16.7]
# Datos pasados final: [18.0, 18.7, 16.5, 16.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-21 21:00:00
# Datos de t-1 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-09-16 21:00:00 [16.2]
# Datos pasados final: [18.7, 16.5, 16.2, 16.7, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-09-20 21:00:00
# Datos de t-1 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-15 21:00:00 [17.6]
# Datos pasados final: [16.5, 16.2, 16.7, 16.2, 17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-19 21:00:00
# Datos de t-1 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-5 días antes: 2022-09-14 21:00:00 [19.0]
# Datos pasados final: [16.2, 16.7, 16.2, 17.6, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-18 21:00:00
# Datos de t-1 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-4 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-09-13 21:00:00 [18.2]
# Datos pasados final: [16.7, 16.2, 17.6, 19.0, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-09-17 21:00:00
# Datos de t-1 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-3 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-12 21:00:00 [18.5]
# Datos pasados final: [16.2, 17.6, 19.0, 18.2, 18.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-16 21:00:00
# Datos de t-1 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-2 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-5 días antes: 2022-09-11 21:00:00 [18.8]
# Datos pasados final: [17.6, 19.0, 18.2, 18.5, 18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-09-15 21:00:00
# Datos de t-1 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-4 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-09-10 21:00:00 [20.2]
# Datos pasados final: [19.0, 18.2, 18.5, 18.8, 20.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-09-14 21:00:00
# Datos de t-1 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-3 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-5 días antes: 2022-09-09 21:00:00 [20.3]
# Datos pasados final: [18.2, 18.5, 18.8, 20.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-13 21:00:00
# Datos de t-1 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-2 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-4 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-09-08 21:00:00 [17.8]
# Datos pasados final: [18.5, 18.8, 20.2, 20.3, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.5): 2022-09-12 21:00:00
# Datos de t-1 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-3 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-07 21:00:00 [17.2]
# Datos pasados final: [18.8, 20.2, 20.3, 17.8, 17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-09-11 21:00:00
# Datos de t-1 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-2 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-5 días antes: 2022-09-06 21:00:00 [15.1]
# Datos pasados final: [20.2, 20.3, 17.8, 17.2, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.2): 2022-09-10 21:00:00
# Datos de t-1 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-4 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-09-05 21:00:00 [17.7]
# Datos pasados final: [20.3, 17.8, 17.2, 15.1, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-09-09 21:00:00
# Datos de t-1 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-3 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-09-04 21:00:00 [18.0]
# Datos pasados final: [17.8, 17.2, 15.1, 17.7, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-09-08 21:00:00
# Datos de t-1 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-2 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-03 21:00:00 [18.0]
# Datos pasados final: [17.2, 15.1, 17.7, 18.0, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-09-07 21:00:00
# Datos de t-1 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-3 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-02 21:00:00 [19.1]
# Datos pasados final: [15.1, 17.7, 18.0, 18.0, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-06 21:00:00
# Datos de t-1 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-2 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-09-01 21:00:00 [20.4]
# Datos pasados final: [17.7, 18.0, 18.0, 19.1, 20.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-09-05 21:00:00
# Datos de t-1 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-4 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-5 días antes: 2022-08-31 21:00:00 [18.7]
# Datos pasados final: [18.0, 18.0, 19.1, 20.4, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-04 21:00:00
# Datos de t-1 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-3 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-4 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-08-30 21:00:00 [19.1]
# Datos pasados final: [18.0, 19.1, 20.4, 18.7, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-03 21:00:00
# Datos de t-1 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-2 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-3 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-08-29 21:00:00 [18.7]
# Datos pasados final: [19.1, 20.4, 18.7, 19.1, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-09-02 21:00:00
# Datos de t-1 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-2 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-4 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-08-28 21:00:00 [14.8]
# Datos pasados final: [20.4, 18.7, 19.1, 18.7, 14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.4): 2022-09-01 21:00:00
# Datos de t-1 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-3 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-5 días antes: 2022-08-27 21:00:00 [20.1]
# Datos pasados final: [18.7, 19.1, 18.7, 14.8, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-31 21:00:00
# Datos de t-1 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-2 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-4 días antes: 2022-08-27 21:00:00 [20.1]
# Datos de t-5 días antes: 2022-08-26 21:00:00 [15.7]
# Datos pasados final: [19.1, 18.7, 14.8, 20.1, 15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-08-30 21:00:00
# Datos de t-1 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-3 días antes: 2022-08-27 21:00:00 [20.1]
# Datos de t-4 días antes: 2022-08-26 21:00:00 [15.7]
# Datos de t-5 días antes: 2022-08-25 21:00:00 [20.1]
# Datos pasados final: [18.7, 14.8, 20.1, 15.7, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-29 21:00:00
# Datos de t-1 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-2 días antes: 2022-08-27 21:00:00 [20.1]
# Datos de t-3 días antes: 2022-08-26 21:00:00 [15.7]
# Datos de t-4 días antes: 2022-08-25 21:00:00 [20.1]
# Datos de t-5 días antes: 2022-08-24 21:00:00 [19.6]
# Datos pasados final: [14.8, 20.1, 15.7, 20.1, 19.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-28 21:00:00
# Datos de t-1 días antes: 2022-08-27 21:00:00 [20.1]
# Datos de t-2 días antes: 2022-08-26 21:00:00 [15.7]
# Datos de t-3 días antes: 2022-08-25 21:00:00 [20.1]
# Datos de t-4 días antes: 2022-08-24 21:00:00 [19.6]
# Datos de t-5 días antes: 2022-08-23 21:00:00 [20.5]
# Datos pasados final: [20.1, 15.7, 20.1, 19.6, 20.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-08-27 21:00:00
# Datos de t-1 días antes: 2022-08-26 21:00:00 [15.7]
# Datos de t-2 días antes: 2022-08-25 21:00:00 [20.1]
# Datos de t-3 días antes: 2022-08-24 21:00:00 [19.6]
# Datos de t-4 días antes: 2022-08-23 21:00:00 [20.5]
# Datos de t-5 días antes: 2022-08-22 21:00:00 [19.2]
# Datos pasados final: [15.7, 20.1, 19.6, 20.5, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-08-26 21:00:00
# Datos de t-1 días antes: 2022-08-25 21:00:00 [20.1]
# Datos de t-2 días antes: 2022-08-24 21:00:00 [19.6]
# Datos de t-3 días antes: 2022-08-23 21:00:00 [20.5]
# Datos de t-4 días antes: 2022-08-22 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-08-21 21:00:00 [19.4]
# Datos pasados final: [20.1, 19.6, 20.5, 19.2, 19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-08-25 21:00:00
# Datos de t-1 días antes: 2022-08-24 21:00:00 [19.6]
# Datos de t-2 días antes: 2022-08-23 21:00:00 [20.5]
# Datos de t-3 días antes: 2022-08-22 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-08-21 21:00:00 [19.4]
# Datos de t-5 días antes: 2022-08-20 21:00:00 [17.4]
# Datos pasados final: [19.6, 20.5, 19.2, 19.4, 17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.6): 2022-08-24 21:00:00
# Datos de t-1 días antes: 2022-08-23 21:00:00 [20.5]
# Datos de t-2 días antes: 2022-08-22 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-08-21 21:00:00 [19.4]
# Datos de t-4 días antes: 2022-08-20 21:00:00 [17.4]
# Datos de t-5 días antes: 2022-08-19 21:00:00 [18.7]
# Datos pasados final: [20.5, 19.2, 19.4, 17.4, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.5): 2022-08-23 21:00:00
# Datos de t-1 días antes: 2022-08-22 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-08-21 21:00:00 [19.4]
# Datos de t-3 días antes: 2022-08-20 21:00:00 [17.4]
# Datos de t-4 días antes: 2022-08-19 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-08-18 21:00:00 [14.5]
# Datos pasados final: [19.2, 19.4, 17.4, 18.7, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-08-22 21:00:00
# Datos de t-1 días antes: 2022-08-21 21:00:00 [19.4]
# Datos de t-2 días antes: 2022-08-20 21:00:00 [17.4]
# Datos de t-3 días antes: 2022-08-19 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-08-18 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-08-17 21:00:00 [19.8]
# Datos pasados final: [19.4, 17.4, 18.7, 14.5, 19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-08-21 21:00:00
# Datos de t-1 días antes: 2022-08-20 21:00:00 [17.4]
# Datos de t-2 días antes: 2022-08-19 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-08-18 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-5 días antes: 2022-08-16 21:00:00 [16.6]
# Datos pasados final: [17.4, 18.7, 14.5, 19.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-20 21:00:00
# Datos de t-1 días antes: 2022-08-19 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-08-18 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-08-15 21:00:00 [14.8]
# Datos pasados final: [18.7, 14.5, 19.8, 16.6, 14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-19 21:00:00
# Datos de t-1 días antes: 2022-08-18 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-5 días antes: 2022-08-14 21:00:00 [19.5]
# Datos pasados final: [14.5, 19.8, 16.6, 14.8, 19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-18 21:00:00
# Datos de t-1 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-4 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-5 días antes: 2022-08-13 21:00:00 [16.9]
# Datos pasados final: [19.8, 16.6, 14.8, 19.5, 16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-17 21:00:00
# Datos de t-1 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-3 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-4 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-5 días antes: 2022-08-12 21:00:00 [15.6]
# Datos pasados final: [16.6, 14.8, 19.5, 16.9, 15.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-16 21:00:00
# Datos de t-1 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-2 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-4 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-5 días antes: 2022-08-11 21:00:00 [20.0]
# Datos pasados final: [14.8, 19.5, 16.9, 15.6, 20.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-15 21:00:00
# Datos de t-1 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-3 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-4 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-5 días antes: 2022-08-10 21:00:00 [19.9]
# Datos pasados final: [19.5, 16.9, 15.6, 20.0, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-08-14 21:00:00
# Datos de t-1 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-2 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-3 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-4 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-08-09 21:00:00 [16.5]
# Datos pasados final: [16.9, 15.6, 20.0, 19.9, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-13 21:00:00
# Datos de t-1 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-2 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-3 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-08-08 21:00:00 [14.9]
# Datos pasados final: [15.6, 20.0, 19.9, 16.5, 14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-2 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-5 días antes: 2022-08-07 21:00:00 [14.5]
# Datos pasados final: [20.0, 19.9, 16.5, 14.9, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-08-06 21:00:00 [18.6]
# Datos pasados final: [19.9, 16.5, 14.9, 14.5, 18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-08-05 21:00:00 [19.8]
# Datos pasados final: [16.5, 14.9, 14.5, 18.6, 19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-5 días antes: 2022-08-04 21:00:00 [18.2]
# Datos pasados final: [14.9, 14.5, 18.6, 19.8, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [14.5, 18.6, 19.8, 18.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [18.6, 19.8, 18.2, 16.7, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [19.8, 18.2, 16.7, 16.7, 17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-5 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [18.2, 16.7, 16.7, 17.4, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-4 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [16.7, 16.7, 17.4, 19.2, 19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-3 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-5 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [16.7, 17.4, 19.2, 19.4, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-2 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-4 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [17.4, 19.2, 19.4, 16.5, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-3 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [19.2, 19.4, 16.5, 16.5, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-2 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [19.4, 16.5, 16.5, 14.4, 19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-5 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.5, 16.5, 14.4, 19.7, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-4 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [16.5, 14.4, 19.7, 16.6, 15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-3 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-5 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [14.4, 19.7, 16.6, 15.5, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-2 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-4 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.7, 16.6, 15.5, 17.7, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-3 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-07-21 21:00:00 [23.3]
# Datos pasados final: [16.6, 15.5, 17.7, 19.9, 23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-25 21:00:00
# Datos de t-1 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-2 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-3 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-5 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [15.5, 17.7, 19.9, 23.3, 24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-07-24 21:00:00
# Datos de t-1 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-2 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-4 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-5 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [17.7, 19.9, 23.3, 24.3, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-07-23 21:00:00
# Datos de t-1 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-3 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-4 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [19.9, 23.3, 24.3, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-07-22 21:00:00
# Datos de t-1 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-2 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-3 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [23.3, 24.3, 17.5, 17.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 23.3): 2022-07-21 21:00:00
# Datos de t-1 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-2 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-07-18 21:00:00 [17.8]
# ...
# Datos pasados final: [17.4, 18.7, 14.5, 19.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-20 21:00:00
# Datos de t-1 días antes: 2022-08-19 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-08-18 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-08-15 21:00:00 [14.8]
# Datos pasados final: [18.7, 14.5, 19.8, 16.6, 14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-08-19 21:00:00
# Datos de t-1 días antes: 2022-08-18 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-5 días antes: 2022-08-14 21:00:00 [19.5]
# Datos pasados final: [14.5, 19.8, 16.6, 14.8, 19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-18 21:00:00
# Datos de t-1 días antes: 2022-08-17 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-4 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-5 días antes: 2022-08-13 21:00:00 [16.9]
# Datos pasados final: [19.8, 16.6, 14.8, 19.5, 16.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-17 21:00:00
# Datos de t-1 días antes: 2022-08-16 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-3 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-4 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-5 días antes: 2022-08-12 21:00:00 [15.6]
# Datos pasados final: [16.6, 14.8, 19.5, 16.9, 15.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-16 21:00:00
# Datos de t-1 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-2 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-4 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-5 días antes: 2022-08-11 21:00:00 [20.0]
# Datos pasados final: [14.8, 19.5, 16.9, 15.6, 20.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-15 21:00:00
# Datos de t-1 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-3 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-4 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-5 días antes: 2022-08-10 21:00:00 [19.9]
# Datos pasados final: [19.5, 16.9, 15.6, 20.0, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-08-14 21:00:00
# Datos de t-1 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-2 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-3 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-4 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-08-09 21:00:00 [16.5]
# Datos pasados final: [16.9, 15.6, 20.0, 19.9, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-13 21:00:00
# Datos de t-1 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-2 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-3 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-08-08 21:00:00 [14.9]
# Datos pasados final: [15.6, 20.0, 19.9, 16.5, 14.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-2 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-5 días antes: 2022-08-07 21:00:00 [14.5]
# Datos pasados final: [20.0, 19.9, 16.5, 14.9, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-08-06 21:00:00 [18.6]
# Datos pasados final: [19.9, 16.5, 14.9, 14.5, 18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-08-05 21:00:00 [19.8]
# Datos pasados final: [16.5, 14.9, 14.5, 18.6, 19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-5 días antes: 2022-08-04 21:00:00 [18.2]
# Datos pasados final: [14.9, 14.5, 18.6, 19.8, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [14.5, 18.6, 19.8, 18.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [18.6, 19.8, 18.2, 16.7, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [19.8, 18.2, 16.7, 16.7, 17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-5 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [18.2, 16.7, 16.7, 17.4, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-4 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [16.7, 16.7, 17.4, 19.2, 19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-3 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-5 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [16.7, 17.4, 19.2, 19.4, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-2 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-4 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [17.4, 19.2, 19.4, 16.5, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-3 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [19.2, 19.4, 16.5, 16.5, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-2 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [19.4, 16.5, 16.5, 14.4, 19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-5 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.5, 16.5, 14.4, 19.7, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-4 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [16.5, 14.4, 19.7, 16.6, 15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-3 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-5 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [14.4, 19.7, 16.6, 15.5, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-2 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-4 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.7, 16.6, 15.5, 17.7, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-3 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-07-21 21:00:00 [23.3]
# Datos pasados final: [16.6, 15.5, 17.7, 19.9, 23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-07-25 21:00:00
# Datos de t-1 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-2 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-3 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-5 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [15.5, 17.7, 19.9, 23.3, 24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.5): 2022-07-24 21:00:00
# Datos de t-1 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-2 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-4 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-5 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [17.7, 19.9, 23.3, 24.3, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-07-23 21:00:00
# Datos de t-1 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-3 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-4 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [19.9, 23.3, 24.3, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-07-22 21:00:00
# Datos de t-1 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-2 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-3 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [23.3, 24.3, 17.5, 17.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 23.3): 2022-07-21 21:00:00
# Datos de t-1 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-2 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-07-17 21:00:00 [16.6]
# Ya no hay más datos hacía atras, o la fecha 2022-07-16 21:00:00 no existe, se omite esta última instancia y termina la iteracion.
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: logs/20221128-054253/ENCB_90_exp2
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name | Type    | Params
# ---------------------------------
# 0 | fc1  | Linear  | 288
# 1 | fc2  | Linear  | 1.2 K
# 2 | out  | Linear  | 25
# 3 | loss | MSELoss | 0
# ---------------------------------
# 1.5 K     Trainable params
# 0         Non-trainable params
# 1.5 K     Total params
# 0.006     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=70` reached.

# %% [markdown]
# ###### pasosPasado=10, pasosFuturo=1, sin Dirección del viento ni Dirección de la ráfaga

# %%
seed_everything(SEED, workers=True)

# Se crea el conjunto de datos
dataENCB90_exp3 = Data_ENCB_90('21:00:00', pasosPasado=10, pasosFuturo=1, excluirColumnasX=["Direcci�n del Viento (grados)","Direcci�n de r�faga (grados)","Rapidez de viento (km/h)","Rapidez de r�faga (km/h)","Humedad relativa (%)","Presi�n Atmosf�rica (hpa)","Precipitaci�n (mm)","Radiaci�n Solar (W/m�)"])
dataENCB90_exp3.prepare_data()
# Se crea el modelo
modelLinReg_exp3 = LinReg(dataENCB90_exp3.X.shape[1], neuronasOcultas=[24*2, 12*2], lr=0.01)

# Se inicializan los registros para el entrenamiento y la prueba
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
logger = TensorBoardLogger(save_dir = logdir, name="ENCB_90_exp3")

# Comienza el entrenamiento
trainer = pl.Trainer(max_epochs=70, logger=logger, log_every_n_steps=1, deterministic=True, accelerator="auto")
trainer.fit(modelLinReg_exp3, dataENCB90_exp3)
# Out:
# INFO:lightning_lite.utilities.seed:Global seed set to 99
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-11 21:00:00
# Datos de t-1 días antes: 2022-11-10 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-5 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-6 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-7 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-9 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-10 días antes: 2022-11-01 21:00:00 [18.4]
# Datos pasados final: [17.9, 16.6, 14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-10 21:00:00
# Datos de t-1 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-4 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-6 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-8 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-9 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-10 días antes: 2022-10-31 21:00:00 [18.2]
# Datos pasados final: [16.6, 14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-11-09 21:00:00
# Datos de t-1 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-3 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-7 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-8 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-9 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-10-30 21:00:00 [19.0]
# Datos pasados final: [14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-11-08 21:00:00
# Datos de t-1 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-2 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-6 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-7 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-8 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-10 días antes: 2022-10-29 21:00:00 [20.1]
# Datos pasados final: [16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-11-07 21:00:00
# Datos de t-1 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-5 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-6 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-7 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-9 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-10 días antes: 2022-10-28 21:00:00 [19.5]
# Datos pasados final: [18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-06 21:00:00
# Datos de t-1 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-4 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-5 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-6 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-8 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-9 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-10 días antes: 2022-10-27 21:00:00 [19.9]
# Datos pasados final: [18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-11-05 21:00:00
# Datos de t-1 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-3 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-4 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-7 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-8 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-9 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-10 días antes: 2022-10-26 21:00:00 [21.1]
# Datos pasados final: [17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-11-04 21:00:00
# Datos de t-1 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-2 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-3 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-6 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-7 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-8 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-9 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-10 días antes: 2022-10-25 21:00:00 [21.1]
# Datos pasados final: [19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.3): 2022-11-03 21:00:00
# Datos de t-1 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-2 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-6 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-7 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-8 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-9 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-10 días antes: 2022-10-24 21:00:00 [21.9]
# Datos pasados final: [17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-02 21:00:00
# Datos de t-1 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-5 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-6 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-8 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-9 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-10 días antes: 2022-10-23 21:00:00 [20.6]
# Datos pasados final: [18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-11-01 21:00:00
# Datos de t-1 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-4 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-5 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-7 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-8 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-9 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-10 días antes: 2022-10-22 21:00:00 [17.0]
# Datos pasados final: [18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-10-31 21:00:00
# Datos de t-1 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-3 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-4 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-6 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-7 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-8 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-9 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-10 días antes: 2022-10-21 21:00:00 [15.9]
# Datos pasados final: [19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-10-30 21:00:00
# Datos de t-1 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-2 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-6 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-7 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-8 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-9 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-10 días antes: 2022-10-20 21:00:00 [18.4]
# Datos pasados final: [20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-10-29 21:00:00
# Datos de t-1 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-6 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-7 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-9 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-10 días antes: 2022-10-19 21:00:00 [13.5]
# Datos pasados final: [19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-10-28 21:00:00
# Datos de t-1 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-5 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-6 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-8 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-9 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-10 días antes: 2022-10-18 21:00:00 [15.0]
# Datos pasados final: [19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-10-27 21:00:00
# Datos de t-1 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-4 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-5 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-7 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-8 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-9 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-10 días antes: 2022-10-17 21:00:00 [15.1]
# Datos pasados final: [21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-26 21:00:00
# Datos de t-1 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-3 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-4 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-6 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-7 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-8 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-9 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-10 días antes: 2022-10-16 21:00:00 [21.2]
# Datos pasados final: [21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-25 21:00:00
# Datos de t-1 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-2 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-3 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-5 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-6 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-7 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-8 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-9 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-10 días antes: 2022-10-15 21:00:00 [20.3]
# Datos pasados final: [21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.9): 2022-10-24 21:00:00
# Datos de t-1 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-2 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-4 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-6 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-7 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-8 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-9 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-10-14 21:00:00 [19.2]
# Datos pasados final: [20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.6): 2022-10-23 21:00:00
# Datos de t-1 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-3 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-5 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-6 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-7 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-8 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-10 días antes: 2022-10-13 21:00:00 [19.1]
# Datos pasados final: [17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-10-22 21:00:00
# Datos de t-1 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-2 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-4 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-5 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-6 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-7 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-9 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-10-12 21:00:00 [20.3]
# Datos pasados final: [15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-10-21 21:00:00
# Datos de t-1 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-3 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-4 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-6 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-8 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-10-11 21:00:00 [17.3]
# Datos pasados final: [18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-10-20 21:00:00
# Datos de t-1 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-2 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-3 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-5 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-7 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-10 días antes: 2022-10-10 21:00:00 [15.7]
# Datos pasados final: [13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.5): 2022-10-19 21:00:00
# Datos de t-1 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-2 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-4 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-6 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-7 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-9 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-10 días antes: 2022-10-09 21:00:00 [14.3]
# Datos pasados final: [15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-18 21:00:00
# Datos de t-1 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-3 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-6 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-8 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-9 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-10 días antes: 2022-10-08 21:00:00 [14.6]
# Datos pasados final: [15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-17 21:00:00
# Datos de t-1 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-2 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-7 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-8 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-9 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-10 días antes: 2022-10-07 21:00:00 [16.6]
# Datos pasados final: [21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.2): 2022-10-16 21:00:00
# Datos de t-1 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-4 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-6 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-7 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-8 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-9 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-10-06 21:00:00 [13.6]
# Datos pasados final: [20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-15 21:00:00
# Datos de t-1 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-3 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-5 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-6 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-7 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-8 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-10 días antes: 2022-10-05 21:00:00 [14.4]
# Datos pasados final: [19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-10-14 21:00:00
# Datos de t-1 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-2 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-4 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-5 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-6 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-7 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-9 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-10 días antes: 2022-10-04 21:00:00 [16.6]
# Datos pasados final: [19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-10-13 21:00:00
# Datos de t-1 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-3 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-4 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-5 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-6 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-8 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-9 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-10-03 21:00:00 [17.5]
# Datos pasados final: [20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-12 21:00:00
# Datos de t-1 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-2 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-3 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-4 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-5 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-7 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-8 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-10-02 21:00:00 [17.5]
# Datos pasados final: [17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-10-11 21:00:00
# Datos de t-1 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-2 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-3 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-4 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-6 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-7 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-10-01 21:00:00 [17.8]
# Datos pasados final: [15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-10-10 21:00:00
# Datos de t-1 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-2 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-3 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-5 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-6 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-09-30 21:00:00 [16.4]
# Datos pasados final: [14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-09 21:00:00
# Datos de t-1 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-2 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-4 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-7 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-10 días antes: 2022-09-29 21:00:00 [14.1]
# Datos pasados final: [14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-10-08 21:00:00
# Datos de t-1 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-3 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-6 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-7 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-8 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-9 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-10 días antes: 2022-09-28 21:00:00 [13.9]
# Datos pasados final: [16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-07 21:00:00
# Datos de t-1 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-2 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-6 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-7 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-8 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-9 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-10 días antes: 2022-09-27 21:00:00 [16.2]
# Datos pasados final: [13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-06 21:00:00
# Datos de t-1 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-6 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-7 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-8 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-9 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-26 21:00:00 [16.2]
# Datos pasados final: [14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-10-05 21:00:00
# Datos de t-1 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-6 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-7 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-8 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-25 21:00:00 [17.0]
# Datos pasados final: [16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-04 21:00:00
# Datos de t-1 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-5 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-6 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-7 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-10 días antes: 2022-09-24 21:00:00 [14.5]
# Datos pasados final: [17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-03 21:00:00
# Datos de t-1 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-4 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-5 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-6 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-9 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-10 días antes: 2022-09-23 21:00:00 [17.9]
# Datos pasados final: [17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-02 21:00:00
# Datos de t-1 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-3 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-4 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-5 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-9 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-10 días antes: 2022-09-22 21:00:00 [18.2]
# Datos pasados final: [17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-10-01 21:00:00
# Datos de t-1 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-2 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-3 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-4 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-8 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-9 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-09-21 21:00:00 [18.0]
# Datos pasados final: [16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-30 21:00:00
# Datos de t-1 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-2 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-3 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-7 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-8 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-20 21:00:00 [18.7]
# Datos pasados final: [14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-09-29 21:00:00
# Datos de t-1 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-2 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-6 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-7 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-09-19 21:00:00 [16.5]
# Datos pasados final: [13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-09-28 21:00:00
# Datos de t-1 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-6 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-09-18 21:00:00 [16.2]
# Datos pasados final: [16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-27 21:00:00
# Datos de t-1 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-5 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-8 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-17 21:00:00 [16.7]
# Datos pasados final: [16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-26 21:00:00
# Datos de t-1 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-4 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-7 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-09-16 21:00:00 [16.2]
# Datos pasados final: [17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-25 21:00:00
# Datos de t-1 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-3 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-6 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-15 21:00:00 [17.6]
# Datos pasados final: [14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-24 21:00:00
# Datos de t-1 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-10 días antes: 2022-09-14 21:00:00 [19.0]
# Datos pasados final: [17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-09-23 21:00:00
# Datos de t-1 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-9 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-10 días antes: 2022-09-13 21:00:00 [18.2]
# Datos pasados final: [18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-22 21:00:00
# Datos de t-1 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-8 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-9 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-09-12 21:00:00 [18.5]
# Datos pasados final: [18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-21 21:00:00
# Datos de t-1 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-7 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-8 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-10 días antes: 2022-09-11 21:00:00 [18.8]
# Datos pasados final: [18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-09-20 21:00:00
# Datos de t-1 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-6 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-7 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-9 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-10 días antes: 2022-09-10 21:00:00 [20.2]
# Datos pasados final: [16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-19 21:00:00
# Datos de t-1 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-5 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-6 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-8 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-9 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-10 días antes: 2022-09-09 21:00:00 [20.3]
# Datos pasados final: [16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-18 21:00:00
# Datos de t-1 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-4 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-7 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-8 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-9 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-09-08 21:00:00 [17.8]
# Datos pasados final: [16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-09-17 21:00:00
# Datos de t-1 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-3 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-6 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-7 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-8 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-09-07 21:00:00 [17.2]
# Datos pasados final: [16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-16 21:00:00
# Datos de t-1 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-2 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-5 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-6 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-7 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-10 días antes: 2022-09-06 21:00:00 [15.1]
# Datos pasados final: [17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-09-15 21:00:00
# Datos de t-1 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-4 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-6 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-8 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-9 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-10 días antes: 2022-09-05 21:00:00 [17.7]
# Datos pasados final: [19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-09-14 21:00:00
# Datos de t-1 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-3 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-5 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-7 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-8 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-9 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-10 días antes: 2022-09-04 21:00:00 [18.0]
# Datos pasados final: [18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-13 21:00:00
# Datos de t-1 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-2 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-4 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-6 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-7 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-8 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-9 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-03 21:00:00 [18.0]
# Datos pasados final: [18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.5): 2022-09-12 21:00:00
# Datos de t-1 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-3 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-6 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-7 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-8 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-02 21:00:00 [19.1]
# Datos pasados final: [18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-09-11 21:00:00
# Datos de t-1 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-2 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-5 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-6 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-7 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-09-01 21:00:00 [20.4]
# Datos pasados final: [20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.2): 2022-09-10 21:00:00
# Datos de t-1 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-4 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-6 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-10 días antes: 2022-08-31 21:00:00 [18.7]
# Datos pasados final: [20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-09-09 21:00:00
# Datos de t-1 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-3 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-9 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-08-30 21:00:00 [19.1]
# Datos pasados final: [17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-09-08 21:00:00
# Datos de t-1 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-2 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-7 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-8 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-08-29 21:00:00 [18.7]
# Datos pasados final: [17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-09-07 21:00:00
# Datos de t-1 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-3 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-6 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-7 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-8 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-08-28 21:00:00 [14.8]
# Datos pasados final: [15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7, 14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-06 21:00:00
# Datos de t-1 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-2 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-6 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-7 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-10 días antes: 2022-08-27 21:00:00 [20.1]
# Datos pasados final: [17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7, 14.8, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-09-05 21:00:00
# Datos de t-1 días antes: 2022-09-04 21:00:00 [18.0]
# ...
# Datos de t-6 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-7 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-8 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-9 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-2 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-5 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-6 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-7 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-8 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-6 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-7 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-6 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-10 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-5 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-9 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-10 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-8 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-9 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-10 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-7 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-8 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-9 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-6 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-7 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-8 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-5 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-6 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-7 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-10 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-4 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-6 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-9 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-10 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-3 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-5 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-8 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-9 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-2 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-4 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-7 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-8 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-10 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-3 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-6 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-7 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-9 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-10 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-2 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-6 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-8 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-9 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-10 días antes: 2022-07-21 21:00:00 [23.3]
# Datos pasados final: [19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-5 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-7 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-8 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-9 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-10 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-4 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-6 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-7 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-8 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-9 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-10 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-3 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-5 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-6 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-8 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-9 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-2 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-4 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-7 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-8 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5, 17.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-3 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-6 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-7 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-07-17 21:00:00 [16.6]
# Ya no hay más datos hacía atras, o la fecha 2022-07-16 21:00:00 no existe, se omite esta última instancia y termina la iteracion.
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: logs/20221128-054318/ENCB_90_exp3
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name | Type    | Params
# ---------------------------------
# 0 | fc1  | Linear  | 528
# 1 | fc2  | Linear  | 1.2 K
# 2 | out  | Linear  | 25
# 3 | loss | MSELoss | 0
# ---------------------------------
# 1.7 K     Trainable params
# 0         Non-trainable params
# 1.7 K     Total params
# 0.007     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=70` reached.

# %% [markdown]
# ### Visualización de resultados

# %% [markdown]
# #### TensorBoard

# %%
# %tensorboard --logdir="logs"

# %%
#best_model_path = trainer.checkpoint_callback.best_model_path
#print(best_model_path)

#model = modelLinReg.load_from_checkpoint(best_model_path)
#model.eval()

#with torch.no_grad():
#    x = torch.Tensor([[[290.0000, 273.0000,   6.3000,  10.2000, 98.0000, 782.3000,0.0000,0.0000]]]) #y_true 13.1
#    y_lgts = model(x)
#    print(y_lgts)

# %% [markdown]
# #### Cálculo de predicciones y métricas

# %% [markdown]
# ###### 9PM pasosPasado=1, pasosFuturo=1, sin Dirección del viento ni Dirección de la ráfaga

# %%
dataENCB90_exp1.show = False
predictions_exp1 = trainer.predict(modelLinReg_exp1, dataENCB90_exp1.val_dataloader())
predictions_list_exp1 = []
for prediction in predictions_exp1[0]:
  predictions_list_exp1.append(float(prediction))
#predictions_list_exp1
test_batch_exp1 = next(iter(dataENCB90_exp1.val_dataloader()))
#test_batch[1]

true_list_exp1 = []
for true in test_batch_exp1[1]:
  true_list_exp1.append(float(true))
true_list_exp1
#dataENCB90.Y_val_horaLocal

lossgraph_exp1 = r2_score(true_list_exp1, predictions_list_exp1) # R2
lossgraph1_exp1 = mean_squared_error(true_list_exp1, predictions_list_exp1) #MSE
lossgraph2_exp1 = mean_squared_error(true_list_exp1, predictions_list_exp1, squared= False) #RMSE
lossgraph3_exp1 = mean_absolute_error(true_list_exp1, predictions_list_exp1) #MAE
# Out:
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-11 21:00:00
# Datos de t-1 días antes: 2022-11-10 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-5 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-6 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-7 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-9 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-10 días antes: 2022-11-01 21:00:00 [18.4]
# Datos pasados final: [17.9, 16.6, 14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-10 21:00:00
# Datos de t-1 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-4 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-6 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-8 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-9 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-10 días antes: 2022-10-31 21:00:00 [18.2]
# Datos pasados final: [16.6, 14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-11-09 21:00:00
# Datos de t-1 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-3 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-7 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-8 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-9 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-10-30 21:00:00 [19.0]
# Datos pasados final: [14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-11-08 21:00:00
# Datos de t-1 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-2 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-6 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-7 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-8 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-10 días antes: 2022-10-29 21:00:00 [20.1]
# Datos pasados final: [16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-11-07 21:00:00
# Datos de t-1 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-5 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-6 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-7 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-9 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-10 días antes: 2022-10-28 21:00:00 [19.5]
# Datos pasados final: [18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-06 21:00:00
# Datos de t-1 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-4 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-5 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-6 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-8 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-9 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-10 días antes: 2022-10-27 21:00:00 [19.9]
# Datos pasados final: [18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-11-05 21:00:00
# Datos de t-1 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-3 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-4 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-7 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-8 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-9 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-10 días antes: 2022-10-26 21:00:00 [21.1]
# Datos pasados final: [17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-11-04 21:00:00
# Datos de t-1 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-2 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-3 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-6 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-7 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-8 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-9 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-10 días antes: 2022-10-25 21:00:00 [21.1]
# Datos pasados final: [19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.3): 2022-11-03 21:00:00
# Datos de t-1 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-2 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-6 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-7 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-8 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-9 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-10 días antes: 2022-10-24 21:00:00 [21.9]
# Datos pasados final: [17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-02 21:00:00
# Datos de t-1 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-5 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-6 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-8 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-9 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-10 días antes: 2022-10-23 21:00:00 [20.6]
# Datos pasados final: [18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-11-01 21:00:00
# Datos de t-1 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-4 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-5 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-7 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-8 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-9 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-10 días antes: 2022-10-22 21:00:00 [17.0]
# Datos pasados final: [18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-10-31 21:00:00
# Datos de t-1 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-3 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-4 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-6 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-7 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-8 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-9 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-10 días antes: 2022-10-21 21:00:00 [15.9]
# Datos pasados final: [19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-10-30 21:00:00
# Datos de t-1 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-2 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-6 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-7 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-8 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-9 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-10 días antes: 2022-10-20 21:00:00 [18.4]
# Datos pasados final: [20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-10-29 21:00:00
# Datos de t-1 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-6 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-7 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-9 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-10 días antes: 2022-10-19 21:00:00 [13.5]
# Datos pasados final: [19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-10-28 21:00:00
# Datos de t-1 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-5 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-6 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-8 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-9 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-10 días antes: 2022-10-18 21:00:00 [15.0]
# Datos pasados final: [19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-10-27 21:00:00
# Datos de t-1 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-4 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-5 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-7 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-8 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-9 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-10 días antes: 2022-10-17 21:00:00 [15.1]
# Datos pasados final: [21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-26 21:00:00
# Datos de t-1 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-3 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-4 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-6 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-7 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-8 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-9 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-10 días antes: 2022-10-16 21:00:00 [21.2]
# Datos pasados final: [21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-25 21:00:00
# Datos de t-1 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-2 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-3 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-5 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-6 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-7 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-8 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-9 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-10 días antes: 2022-10-15 21:00:00 [20.3]
# Datos pasados final: [21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.9): 2022-10-24 21:00:00
# Datos de t-1 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-2 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-4 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-6 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-7 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-8 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-9 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-10-14 21:00:00 [19.2]
# Datos pasados final: [20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.6): 2022-10-23 21:00:00
# Datos de t-1 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-3 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-5 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-6 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-7 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-8 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-10 días antes: 2022-10-13 21:00:00 [19.1]
# Datos pasados final: [17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-10-22 21:00:00
# Datos de t-1 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-2 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-4 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-5 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-6 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-7 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-9 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-10-12 21:00:00 [20.3]
# Datos pasados final: [15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-10-21 21:00:00
# Datos de t-1 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-3 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-4 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-6 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-8 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-10-11 21:00:00 [17.3]
# Datos pasados final: [18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-10-20 21:00:00
# Datos de t-1 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-2 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-3 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-5 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-7 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-10 días antes: 2022-10-10 21:00:00 [15.7]
# Datos pasados final: [13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.5): 2022-10-19 21:00:00
# Datos de t-1 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-2 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-4 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-6 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-7 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-9 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-10 días antes: 2022-10-09 21:00:00 [14.3]
# Datos pasados final: [15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-18 21:00:00
# Datos de t-1 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-3 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-6 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-8 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-9 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-10 días antes: 2022-10-08 21:00:00 [14.6]
# Datos pasados final: [15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-17 21:00:00
# Datos de t-1 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-2 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-7 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-8 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-9 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-10 días antes: 2022-10-07 21:00:00 [16.6]
# Datos pasados final: [21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.2): 2022-10-16 21:00:00
# Datos de t-1 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-4 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-6 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-7 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-8 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-9 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-10-06 21:00:00 [13.6]
# Datos pasados final: [20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-15 21:00:00
# Datos de t-1 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-3 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-5 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-6 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-7 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-8 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-10 días antes: 2022-10-05 21:00:00 [14.4]
# Datos pasados final: [19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-10-14 21:00:00
# Datos de t-1 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-2 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-4 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-5 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-6 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-7 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-9 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-10 días antes: 2022-10-04 21:00:00 [16.6]
# Datos pasados final: [19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-10-13 21:00:00
# Datos de t-1 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-3 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-4 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-5 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-6 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-8 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-9 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-10-03 21:00:00 [17.5]
# Datos pasados final: [20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-12 21:00:00
# Datos de t-1 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-2 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-3 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-4 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-5 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-7 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-8 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-10-02 21:00:00 [17.5]
# Datos pasados final: [17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-10-11 21:00:00
# Datos de t-1 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-2 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-3 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-4 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-6 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-7 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-10-01 21:00:00 [17.8]
# Datos pasados final: [15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-10-10 21:00:00
# Datos de t-1 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-2 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-3 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-5 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-6 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-09-30 21:00:00 [16.4]
# Datos pasados final: [14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-09 21:00:00
# Datos de t-1 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-2 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-4 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-7 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-10 días antes: 2022-09-29 21:00:00 [14.1]
# Datos pasados final: [14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-10-08 21:00:00
# Datos de t-1 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-3 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-6 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-7 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-8 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-9 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-10 días antes: 2022-09-28 21:00:00 [13.9]
# Datos pasados final: [16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-07 21:00:00
# Datos de t-1 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-2 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-6 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-7 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-8 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-9 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-10 días antes: 2022-09-27 21:00:00 [16.2]
# Datos pasados final: [13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-06 21:00:00
# Datos de t-1 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-6 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-7 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-8 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-9 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-26 21:00:00 [16.2]
# Datos pasados final: [14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-10-05 21:00:00
# Datos de t-1 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-6 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-7 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-8 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-25 21:00:00 [17.0]
# Datos pasados final: [16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-04 21:00:00
# Datos de t-1 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-5 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-6 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-7 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-10 días antes: 2022-09-24 21:00:00 [14.5]
# Datos pasados final: [17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-03 21:00:00
# Datos de t-1 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-4 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-5 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-6 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-9 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-10 días antes: 2022-09-23 21:00:00 [17.9]
# Datos pasados final: [17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-02 21:00:00
# Datos de t-1 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-3 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-4 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-5 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-9 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-10 días antes: 2022-09-22 21:00:00 [18.2]
# Datos pasados final: [17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-10-01 21:00:00
# Datos de t-1 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-2 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-3 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-4 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-8 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-9 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-09-21 21:00:00 [18.0]
# Datos pasados final: [16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-30 21:00:00
# Datos de t-1 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-2 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-3 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-7 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-8 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-20 21:00:00 [18.7]
# Datos pasados final: [14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-09-29 21:00:00
# Datos de t-1 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-2 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-6 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-7 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-09-19 21:00:00 [16.5]
# Datos pasados final: [13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-09-28 21:00:00
# Datos de t-1 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-6 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-09-18 21:00:00 [16.2]
# Datos pasados final: [16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-27 21:00:00
# Datos de t-1 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-5 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-8 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-17 21:00:00 [16.7]
# Datos pasados final: [16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-26 21:00:00
# Datos de t-1 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-4 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-7 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-09-16 21:00:00 [16.2]
# Datos pasados final: [17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-25 21:00:00
# Datos de t-1 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-3 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-6 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-15 21:00:00 [17.6]
# Datos pasados final: [14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-24 21:00:00
# Datos de t-1 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-10 días antes: 2022-09-14 21:00:00 [19.0]
# Datos pasados final: [17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-09-23 21:00:00
# Datos de t-1 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-9 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-10 días antes: 2022-09-13 21:00:00 [18.2]
# Datos pasados final: [18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-22 21:00:00
# Datos de t-1 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-8 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-9 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-09-12 21:00:00 [18.5]
# Datos pasados final: [18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-21 21:00:00
# Datos de t-1 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-7 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-8 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-10 días antes: 2022-09-11 21:00:00 [18.8]
# Datos pasados final: [18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-09-20 21:00:00
# Datos de t-1 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-6 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-7 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-9 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-10 días antes: 2022-09-10 21:00:00 [20.2]
# Datos pasados final: [16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-19 21:00:00
# Datos de t-1 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-5 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-6 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-8 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-9 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-10 días antes: 2022-09-09 21:00:00 [20.3]
# Datos pasados final: [16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-18 21:00:00
# Datos de t-1 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-4 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-7 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-8 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-9 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-09-08 21:00:00 [17.8]
# Datos pasados final: [16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-09-17 21:00:00
# Datos de t-1 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-3 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-6 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-7 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-8 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-09-07 21:00:00 [17.2]
# Datos pasados final: [16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-16 21:00:00
# Datos de t-1 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-2 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-5 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-6 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-7 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-10 días antes: 2022-09-06 21:00:00 [15.1]
# Datos pasados final: [17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-09-15 21:00:00
# Datos de t-1 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-4 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-6 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-8 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-9 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-10 días antes: 2022-09-05 21:00:00 [17.7]
# Datos pasados final: [19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-09-14 21:00:00
# Datos de t-1 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-3 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-5 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-7 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-8 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-9 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-10 días antes: 2022-09-04 21:00:00 [18.0]
# Datos pasados final: [18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-13 21:00:00
# Datos de t-1 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-2 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-4 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-6 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-7 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-8 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-9 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-03 21:00:00 [18.0]
# Datos pasados final: [18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.5): 2022-09-12 21:00:00
# Datos de t-1 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-3 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-6 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-7 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-8 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-02 21:00:00 [19.1]
# Datos pasados final: [18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-09-11 21:00:00
# Datos de t-1 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-2 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-5 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-6 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-7 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-09-01 21:00:00 [20.4]
# Datos pasados final: [20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.2): 2022-09-10 21:00:00
# Datos de t-1 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-4 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-6 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-10 días antes: 2022-08-31 21:00:00 [18.7]
# Datos pasados final: [20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-09-09 21:00:00
# Datos de t-1 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-3 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-9 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-08-30 21:00:00 [19.1]
# Datos pasados final: [17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-09-08 21:00:00
# Datos de t-1 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-2 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-7 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-8 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-08-29 21:00:00 [18.7]
# Datos pasados final: [17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-09-07 21:00:00
# Datos de t-1 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-3 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-6 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-7 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-8 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-08-28 21:00:00 [14.8]
# Datos pasados final: [15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7, 14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-06 21:00:00
# Datos de t-1 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-2 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-6 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-7 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-10 días antes: 2022-08-27 21:00:00 [20.1]
# Datos pasados final: [17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7, 14.8, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-09-05 21:00:00
# Datos de t-1 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-03 21:00:00 [18.0]
# ...
# Datos de t-8 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-10 días antes: 2022-08-07 21:00:00 [14.5]
# Datos pasados final: [16.6, 14.8, 19.5, 16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-16 21:00:00
# Datos de t-1 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-2 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-4 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-5 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-6 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-9 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-10 días antes: 2022-08-06 21:00:00 [18.6]
# Datos pasados final: [14.8, 19.5, 16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-15 21:00:00
# Datos de t-1 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-3 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-4 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-5 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-8 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-9 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-10 días antes: 2022-08-05 21:00:00 [19.8]
# Datos pasados final: [19.5, 16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-08-14 21:00:00
# Datos de t-1 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-2 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-3 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-4 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-7 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-8 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-9 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-10 días antes: 2022-08-04 21:00:00 [18.2]
# Datos pasados final: [16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-13 21:00:00
# Datos de t-1 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-2 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-3 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-6 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-7 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-8 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-9 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-2 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-5 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-6 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-7 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-8 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-6 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-7 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-6 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-10 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-5 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-9 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-10 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-8 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-9 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-10 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-7 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-8 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-9 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-6 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-7 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-8 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-5 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-6 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-7 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-10 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-4 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-6 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-9 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-10 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-3 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-5 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-8 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-9 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-2 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-4 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-7 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-8 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-10 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-3 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-6 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-7 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-9 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-10 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-2 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-6 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-8 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-9 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-10 días antes: 2022-07-21 21:00:00 [23.3]
# Datos pasados final: [19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-5 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-7 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-8 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-9 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-10 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-4 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-6 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-7 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-8 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-9 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-10 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-3 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-5 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-6 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-8 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-9 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-2 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-4 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-7 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-8 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5, 17.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-3 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-6 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-7 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-07-17 21:00:00 [16.6]
# Ya no hay más datos hacía atras, o la fecha 2022-07-16 21:00:00 no existe, se omite esta última instancia y termina la iteracion.
# Predicting: 1it [00:00, ?it/s]

# %% [markdown]
# ###### 9PM pasosPasado=5, pasosFuturo=1, sin Dirección del viento ni Dirección de la ráfaga

# %%
dataENCB90_exp2.show = False
predictions_exp2 = trainer.predict(modelLinReg_exp2, dataENCB90_exp2.val_dataloader())
predictions_list_exp2 = []
for prediction in predictions_exp2[0]:
  predictions_list_exp2.append(float(prediction))
#predictions_list_exp1
test_batch_exp2 = next(iter(dataENCB90_exp2.val_dataloader()))
#test_batch[1]

true_list_exp2 = []
for true in test_batch_exp2[1]:
  true_list_exp2.append(float(true))
true_list_exp2
#dataENCB90.Y_val_horaLocal

lossgraph_exp2 = r2_score(true_list_exp2, predictions_list_exp2) # R2
lossgraph1_exp2 = mean_squared_error(true_list_exp2, predictions_list_exp2) #MSE
lossgraph2_exp2 = mean_squared_error(true_list_exp2, predictions_list_exp2, squared= False) #RMSE
lossgraph3_exp2 = mean_absolute_error(true_list_exp2, predictions_list_exp2) #MAE
# Out:
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-11 21:00:00
# Datos de t-1 días antes: 2022-11-10 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-5 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-6 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-7 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-9 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-10 días antes: 2022-11-01 21:00:00 [18.4]
# Datos pasados final: [17.9, 16.6, 14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-11-10 21:00:00
# Datos de t-1 días antes: 2022-11-09 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-4 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-6 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-8 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-9 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-10 días antes: 2022-10-31 21:00:00 [18.2]
# Datos pasados final: [16.6, 14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-11-09 21:00:00
# Datos de t-1 días antes: 2022-11-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-3 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-7 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-8 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-9 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-10-30 21:00:00 [19.0]
# Datos pasados final: [14.9, 16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-11-08 21:00:00
# Datos de t-1 días antes: 2022-11-07 21:00:00 [16.8]
# Datos de t-2 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-6 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-7 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-8 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-10 días antes: 2022-10-29 21:00:00 [20.1]
# Datos pasados final: [16.8, 18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.8): 2022-11-07 21:00:00
# Datos de t-1 días antes: 2022-11-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-5 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-6 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-7 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-9 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-10 días antes: 2022-10-28 21:00:00 [19.5]
# Datos pasados final: [18.6, 18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-11-06 21:00:00
# Datos de t-1 días antes: 2022-11-05 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-4 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-5 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-6 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-8 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-9 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-10 días antes: 2022-10-27 21:00:00 [19.9]
# Datos pasados final: [18.8, 17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-11-05 21:00:00
# Datos de t-1 días antes: 2022-11-04 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-3 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-4 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-7 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-8 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-9 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-10 días antes: 2022-10-26 21:00:00 [21.1]
# Datos pasados final: [17.0, 19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-11-04 21:00:00
# Datos de t-1 días antes: 2022-11-03 21:00:00 [19.3]
# Datos de t-2 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-3 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-6 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-7 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-8 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-9 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-10 días antes: 2022-10-25 21:00:00 [21.1]
# Datos pasados final: [19.3, 17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.3): 2022-11-03 21:00:00
# Datos de t-1 días antes: 2022-11-02 21:00:00 [17.1]
# Datos de t-2 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-6 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-7 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-8 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-9 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-10 días antes: 2022-10-24 21:00:00 [21.9]
# Datos pasados final: [17.1, 18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.1): 2022-11-02 21:00:00
# Datos de t-1 días antes: 2022-11-01 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-5 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-6 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-8 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-9 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-10 días antes: 2022-10-23 21:00:00 [20.6]
# Datos pasados final: [18.4, 18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-11-01 21:00:00
# Datos de t-1 días antes: 2022-10-31 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-4 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-5 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-7 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-8 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-9 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-10 días antes: 2022-10-22 21:00:00 [17.0]
# Datos pasados final: [18.2, 19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-10-31 21:00:00
# Datos de t-1 días antes: 2022-10-30 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-3 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-4 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-6 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-7 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-8 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-9 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-10 días antes: 2022-10-21 21:00:00 [15.9]
# Datos pasados final: [19.0, 20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-10-30 21:00:00
# Datos de t-1 días antes: 2022-10-29 21:00:00 [20.1]
# Datos de t-2 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-6 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-7 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-8 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-9 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-10 días antes: 2022-10-20 21:00:00 [18.4]
# Datos pasados final: [20.1, 19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.1): 2022-10-29 21:00:00
# Datos de t-1 días antes: 2022-10-28 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-5 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-6 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-7 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-9 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-10 días antes: 2022-10-19 21:00:00 [13.5]
# Datos pasados final: [19.5, 19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-10-28 21:00:00
# Datos de t-1 días antes: 2022-10-27 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-4 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-5 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-6 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-8 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-9 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-10 días antes: 2022-10-18 21:00:00 [15.0]
# Datos pasados final: [19.9, 21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-10-27 21:00:00
# Datos de t-1 días antes: 2022-10-26 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-3 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-4 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-5 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-7 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-8 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-9 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-10 días antes: 2022-10-17 21:00:00 [15.1]
# Datos pasados final: [21.1, 21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-26 21:00:00
# Datos de t-1 días antes: 2022-10-25 21:00:00 [21.1]
# Datos de t-2 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-3 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-4 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-6 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-7 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-8 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-9 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-10 días antes: 2022-10-16 21:00:00 [21.2]
# Datos pasados final: [21.1, 21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.1): 2022-10-25 21:00:00
# Datos de t-1 días antes: 2022-10-24 21:00:00 [21.9]
# Datos de t-2 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-3 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-5 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-6 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-7 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-8 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-9 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-10 días antes: 2022-10-15 21:00:00 [20.3]
# Datos pasados final: [21.9, 20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.9): 2022-10-24 21:00:00
# Datos de t-1 días antes: 2022-10-23 21:00:00 [20.6]
# Datos de t-2 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-4 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-5 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-6 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-7 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-8 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-9 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-10-14 21:00:00 [19.2]
# Datos pasados final: [20.6, 17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.6): 2022-10-23 21:00:00
# Datos de t-1 días antes: 2022-10-22 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-3 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-4 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-5 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-6 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-7 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-8 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-10 días antes: 2022-10-13 21:00:00 [19.1]
# Datos pasados final: [17.0, 15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-10-22 21:00:00
# Datos de t-1 días antes: 2022-10-21 21:00:00 [15.9]
# Datos de t-2 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-3 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-4 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-5 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-6 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-7 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-9 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-10-12 21:00:00 [20.3]
# Datos pasados final: [15.9, 18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.9): 2022-10-21 21:00:00
# Datos de t-1 días antes: 2022-10-20 21:00:00 [18.4]
# Datos de t-2 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-3 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-4 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-6 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-8 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-10-11 21:00:00 [17.3]
# Datos pasados final: [18.4, 13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.4): 2022-10-20 21:00:00
# Datos de t-1 días antes: 2022-10-19 21:00:00 [13.5]
# Datos de t-2 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-3 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-5 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-7 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-10 días antes: 2022-10-10 21:00:00 [15.7]
# Datos pasados final: [13.5, 15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.5): 2022-10-19 21:00:00
# Datos de t-1 días antes: 2022-10-18 21:00:00 [15.0]
# Datos de t-2 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-4 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-6 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-7 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-9 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-10 días antes: 2022-10-09 21:00:00 [14.3]
# Datos pasados final: [15.0, 15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.0): 2022-10-18 21:00:00
# Datos de t-1 días antes: 2022-10-17 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-3 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-6 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-8 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-9 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-10 días antes: 2022-10-08 21:00:00 [14.6]
# Datos pasados final: [15.1, 21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-10-17 21:00:00
# Datos de t-1 días antes: 2022-10-16 21:00:00 [21.2]
# Datos de t-2 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-7 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-8 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-9 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-10 días antes: 2022-10-07 21:00:00 [16.6]
# Datos pasados final: [21.2, 20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 21.2): 2022-10-16 21:00:00
# Datos de t-1 días antes: 2022-10-15 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-4 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-6 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-7 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-8 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-9 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-10-06 21:00:00 [13.6]
# Datos pasados final: [20.3, 19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-15 21:00:00
# Datos de t-1 días antes: 2022-10-14 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-3 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-5 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-6 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-7 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-8 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-10 días antes: 2022-10-05 21:00:00 [14.4]
# Datos pasados final: [19.2, 19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-10-14 21:00:00
# Datos de t-1 días antes: 2022-10-13 21:00:00 [19.1]
# Datos de t-2 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-4 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-5 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-6 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-7 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-9 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-10 días antes: 2022-10-04 21:00:00 [16.6]
# Datos pasados final: [19.1, 20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.1): 2022-10-13 21:00:00
# Datos de t-1 días antes: 2022-10-12 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-3 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-4 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-5 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-6 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-8 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-9 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-10-03 21:00:00 [17.5]
# Datos pasados final: [20.3, 17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-10-12 21:00:00
# Datos de t-1 días antes: 2022-10-11 21:00:00 [17.3]
# Datos de t-2 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-3 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-4 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-5 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-7 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-8 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-10-02 21:00:00 [17.5]
# Datos pasados final: [17.3, 15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.3): 2022-10-11 21:00:00
# Datos de t-1 días antes: 2022-10-10 21:00:00 [15.7]
# Datos de t-2 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-3 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-4 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-6 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-7 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-10-01 21:00:00 [17.8]
# Datos pasados final: [15.7, 14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.7): 2022-10-10 21:00:00
# Datos de t-1 días antes: 2022-10-09 21:00:00 [14.3]
# Datos de t-2 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-3 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-5 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-6 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-09-30 21:00:00 [16.4]
# Datos pasados final: [14.3, 14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.3): 2022-10-09 21:00:00
# Datos de t-1 días antes: 2022-10-08 21:00:00 [14.6]
# Datos de t-2 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-4 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-7 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-10 días antes: 2022-09-29 21:00:00 [14.1]
# Datos pasados final: [14.6, 16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.6): 2022-10-08 21:00:00
# Datos de t-1 días antes: 2022-10-07 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-3 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-6 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-7 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-8 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-9 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-10 días antes: 2022-09-28 21:00:00 [13.9]
# Datos pasados final: [16.6, 13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-07 21:00:00
# Datos de t-1 días antes: 2022-10-06 21:00:00 [13.6]
# Datos de t-2 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-6 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-7 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-8 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-9 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-10 días antes: 2022-09-27 21:00:00 [16.2]
# Datos pasados final: [13.6, 14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.6): 2022-10-06 21:00:00
# Datos de t-1 días antes: 2022-10-05 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-5 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-6 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-7 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-8 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-9 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-26 21:00:00 [16.2]
# Datos pasados final: [14.4, 16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-10-05 21:00:00
# Datos de t-1 días antes: 2022-10-04 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-4 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-6 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-7 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-8 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-25 21:00:00 [17.0]
# Datos pasados final: [16.6, 17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-10-04 21:00:00
# Datos de t-1 días antes: 2022-10-03 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-3 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-5 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-6 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-7 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-10 días antes: 2022-09-24 21:00:00 [14.5]
# Datos pasados final: [17.5, 17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-03 21:00:00
# Datos de t-1 días antes: 2022-10-02 21:00:00 [17.5]
# Datos de t-2 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-4 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-5 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-6 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-9 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-10 días antes: 2022-09-23 21:00:00 [17.9]
# Datos pasados final: [17.5, 17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.5): 2022-10-02 21:00:00
# Datos de t-1 días antes: 2022-10-01 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-3 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-4 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-5 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-8 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-9 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-10 días antes: 2022-09-22 21:00:00 [18.2]
# Datos pasados final: [17.8, 16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-10-01 21:00:00
# Datos de t-1 días antes: 2022-09-30 21:00:00 [16.4]
# Datos de t-2 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-3 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-4 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-7 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-8 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-9 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-09-21 21:00:00 [18.0]
# Datos pasados final: [16.4, 14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.4): 2022-09-30 21:00:00
# Datos de t-1 días antes: 2022-09-29 21:00:00 [14.1]
# Datos de t-2 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-3 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-6 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-7 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-8 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-20 21:00:00 [18.7]
# Datos pasados final: [14.1, 13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.1): 2022-09-29 21:00:00
# Datos de t-1 días antes: 2022-09-28 21:00:00 [13.9]
# Datos de t-2 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-5 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-6 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-7 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-09-19 21:00:00 [16.5]
# Datos pasados final: [13.9, 16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 13.9): 2022-09-28 21:00:00
# Datos de t-1 días antes: 2022-09-27 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-4 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-6 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-09-18 21:00:00 [16.2]
# Datos pasados final: [16.2, 16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-27 21:00:00
# Datos de t-1 días antes: 2022-09-26 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-3 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-5 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-8 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-17 21:00:00 [16.7]
# Datos pasados final: [16.2, 17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-26 21:00:00
# Datos de t-1 días antes: 2022-09-25 21:00:00 [17.0]
# Datos de t-2 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-4 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-7 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-09-16 21:00:00 [16.2]
# Datos pasados final: [17.0, 14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.0): 2022-09-25 21:00:00
# Datos de t-1 días antes: 2022-09-24 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-3 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-6 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-10 días antes: 2022-09-15 21:00:00 [17.6]
# Datos pasados final: [14.5, 17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-09-24 21:00:00
# Datos de t-1 días antes: 2022-09-23 21:00:00 [17.9]
# Datos de t-2 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-5 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-9 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-10 días antes: 2022-09-14 21:00:00 [19.0]
# Datos pasados final: [17.9, 18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.9): 2022-09-23 21:00:00
# Datos de t-1 días antes: 2022-09-22 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-4 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-8 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-9 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-10 días antes: 2022-09-13 21:00:00 [18.2]
# Datos pasados final: [18.2, 18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-22 21:00:00
# Datos de t-1 días antes: 2022-09-21 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-3 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-7 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-8 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-9 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-09-12 21:00:00 [18.5]
# Datos pasados final: [18.0, 18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.0): 2022-09-21 21:00:00
# Datos de t-1 días antes: 2022-09-20 21:00:00 [18.7]
# Datos de t-2 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-6 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-7 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-8 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-10 días antes: 2022-09-11 21:00:00 [18.8]
# Datos pasados final: [18.7, 16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.7): 2022-09-20 21:00:00
# Datos de t-1 días antes: 2022-09-19 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-5 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-6 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-7 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-9 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-10 días antes: 2022-09-10 21:00:00 [20.2]
# Datos pasados final: [16.5, 16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-09-19 21:00:00
# Datos de t-1 días antes: 2022-09-18 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-4 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-5 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-6 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-8 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-9 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-10 días antes: 2022-09-09 21:00:00 [20.3]
# Datos pasados final: [16.2, 16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-18 21:00:00
# Datos de t-1 días antes: 2022-09-17 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-3 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-4 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-5 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-7 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-8 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-9 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-10 días antes: 2022-09-08 21:00:00 [17.8]
# Datos pasados final: [16.7, 16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-09-17 21:00:00
# Datos de t-1 días antes: 2022-09-16 21:00:00 [16.2]
# Datos de t-2 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-3 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-4 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-6 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-7 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-8 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-9 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-09-07 21:00:00 [17.2]
# Datos pasados final: [16.2, 17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.2): 2022-09-16 21:00:00
# Datos de t-1 días antes: 2022-09-15 21:00:00 [17.6]
# Datos de t-2 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-3 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-5 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-6 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-7 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-8 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-10 días antes: 2022-09-06 21:00:00 [15.1]
# Datos pasados final: [17.6, 19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.6): 2022-09-15 21:00:00
# Datos de t-1 días antes: 2022-09-14 21:00:00 [19.0]
# Datos de t-2 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-4 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-5 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-6 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-7 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-8 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-9 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-10 días antes: 2022-09-05 21:00:00 [17.7]
# Datos pasados final: [19.0, 18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.0): 2022-09-14 21:00:00
# Datos de t-1 días antes: 2022-09-13 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-3 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-4 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-5 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-6 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-7 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-8 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-9 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-10 días antes: 2022-09-04 21:00:00 [18.0]
# Datos pasados final: [18.2, 18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-09-13 21:00:00
# Datos de t-1 días antes: 2022-09-12 21:00:00 [18.5]
# Datos de t-2 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-3 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-4 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-5 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-6 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-7 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-8 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-9 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-03 21:00:00 [18.0]
# Datos pasados final: [18.5, 18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.5): 2022-09-12 21:00:00
# Datos de t-1 días antes: 2022-09-11 21:00:00 [18.8]
# Datos de t-2 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-3 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-4 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-5 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-6 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-7 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-8 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-10 días antes: 2022-09-02 21:00:00 [19.1]
# Datos pasados final: [18.8, 20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.8): 2022-09-11 21:00:00
# Datos de t-1 días antes: 2022-09-10 21:00:00 [20.2]
# Datos de t-2 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-3 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-4 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-5 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-6 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-7 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-9 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-09-01 21:00:00 [20.4]
# Datos pasados final: [20.2, 20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.2): 2022-09-10 21:00:00
# Datos de t-1 días antes: 2022-09-09 21:00:00 [20.3]
# Datos de t-2 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-3 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-4 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-5 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-6 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-8 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-10 días antes: 2022-08-31 21:00:00 [18.7]
# Datos pasados final: [20.3, 17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.3): 2022-09-09 21:00:00
# Datos de t-1 días antes: 2022-09-08 21:00:00 [17.8]
# Datos de t-2 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-3 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-4 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-7 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-9 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-08-30 21:00:00 [19.1]
# Datos pasados final: [17.8, 17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.8): 2022-09-08 21:00:00
# Datos de t-1 días antes: 2022-09-07 21:00:00 [17.2]
# Datos de t-2 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-3 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-6 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-7 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-8 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-10 días antes: 2022-08-29 21:00:00 [18.7]
# Datos pasados final: [17.2, 15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.2): 2022-09-07 21:00:00
# Datos de t-1 días antes: 2022-09-06 21:00:00 [15.1]
# Datos de t-2 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-3 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-5 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-6 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-7 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-8 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-9 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-10 días antes: 2022-08-28 21:00:00 [14.8]
# Datos pasados final: [15.1, 17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7, 14.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.1): 2022-09-06 21:00:00
# Datos de t-1 días antes: 2022-09-05 21:00:00 [17.7]
# Datos de t-2 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-3 días antes: 2022-09-03 21:00:00 [18.0]
# Datos de t-4 días antes: 2022-09-02 21:00:00 [19.1]
# Datos de t-5 días antes: 2022-09-01 21:00:00 [20.4]
# Datos de t-6 días antes: 2022-08-31 21:00:00 [18.7]
# Datos de t-7 días antes: 2022-08-30 21:00:00 [19.1]
# Datos de t-8 días antes: 2022-08-29 21:00:00 [18.7]
# Datos de t-9 días antes: 2022-08-28 21:00:00 [14.8]
# Datos de t-10 días antes: 2022-08-27 21:00:00 [20.1]
# Datos pasados final: [17.7, 18.0, 18.0, 19.1, 20.4, 18.7, 19.1, 18.7, 14.8, 20.1]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.7): 2022-09-05 21:00:00
# Datos de t-1 días antes: 2022-09-04 21:00:00 [18.0]
# Datos de t-2 días antes: 2022-09-03 21:00:00 [18.0]
# ...
# Datos de t-8 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-10 días antes: 2022-08-07 21:00:00 [14.5]
# Datos pasados final: [16.6, 14.8, 19.5, 16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.6): 2022-08-16 21:00:00
# Datos de t-1 días antes: 2022-08-15 21:00:00 [14.8]
# Datos de t-2 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-3 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-4 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-5 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-6 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-9 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-10 días antes: 2022-08-06 21:00:00 [18.6]
# Datos pasados final: [14.8, 19.5, 16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.8): 2022-08-15 21:00:00
# Datos de t-1 días antes: 2022-08-14 21:00:00 [19.5]
# Datos de t-2 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-3 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-4 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-5 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-8 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-9 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-10 días antes: 2022-08-05 21:00:00 [19.8]
# Datos pasados final: [19.5, 16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.5): 2022-08-14 21:00:00
# Datos de t-1 días antes: 2022-08-13 21:00:00 [16.9]
# Datos de t-2 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-3 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-4 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-7 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-8 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-9 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-10 días antes: 2022-08-04 21:00:00 [18.2]
# Datos pasados final: [16.9, 15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.9): 2022-08-13 21:00:00
# Datos de t-1 días antes: 2022-08-12 21:00:00 [15.6]
# Datos de t-2 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-3 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-4 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-6 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-7 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-8 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-9 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-10 días antes: 2022-08-03 21:00:00 [16.7]
# Datos pasados final: [15.6, 20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 15.6): 2022-08-12 21:00:00
# Datos de t-1 días antes: 2022-08-11 21:00:00 [20.0]
# Datos de t-2 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-3 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-5 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-6 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-7 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-8 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-9 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-08-02 21:00:00 [16.7]
# Datos pasados final: [20.0, 19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 20.0): 2022-08-11 21:00:00
# Datos de t-1 días antes: 2022-08-10 21:00:00 [19.9]
# Datos de t-2 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-4 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-5 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-6 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-7 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-8 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-10 días antes: 2022-08-01 21:00:00 [17.4]
# Datos pasados final: [19.9, 16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.9): 2022-08-10 21:00:00
# Datos de t-1 días antes: 2022-08-09 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-3 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-4 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-5 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-6 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-7 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-9 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-10 días antes: 2022-07-31 21:00:00 [19.2]
# Datos pasados final: [16.5, 14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-08-09 21:00:00
# Datos de t-1 días antes: 2022-08-08 21:00:00 [14.9]
# Datos de t-2 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-3 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-4 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-5 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-6 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-8 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-9 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-10 días antes: 2022-07-30 21:00:00 [19.4]
# Datos pasados final: [14.9, 14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.9): 2022-08-08 21:00:00
# Datos de t-1 días antes: 2022-08-07 21:00:00 [14.5]
# Datos de t-2 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-3 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-4 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-5 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-7 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-8 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-9 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-10 días antes: 2022-07-29 21:00:00 [16.5]
# Datos pasados final: [14.5, 18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.5): 2022-08-07 21:00:00
# Datos de t-1 días antes: 2022-08-06 21:00:00 [18.6]
# Datos de t-2 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-3 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-4 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-6 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-7 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-8 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-9 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-07-28 21:00:00 [16.5]
# Datos pasados final: [18.6, 19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.6): 2022-08-06 21:00:00
# Datos de t-1 días antes: 2022-08-05 21:00:00 [19.8]
# Datos de t-2 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-3 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-5 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-6 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-7 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-8 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-10 días antes: 2022-07-27 21:00:00 [14.4]
# Datos pasados final: [19.8, 18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.8): 2022-08-05 21:00:00
# Datos de t-1 días antes: 2022-08-04 21:00:00 [18.2]
# Datos de t-2 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-4 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-5 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-6 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-7 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-9 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-10 días antes: 2022-07-26 21:00:00 [19.7]
# Datos pasados final: [18.2, 16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 18.2): 2022-08-04 21:00:00
# Datos de t-1 días antes: 2022-08-03 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-3 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-4 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-5 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-6 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-8 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-9 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-10 días antes: 2022-07-25 21:00:00 [16.6]
# Datos pasados final: [16.7, 16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-03 21:00:00
# Datos de t-1 días antes: 2022-08-02 21:00:00 [16.7]
# Datos de t-2 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-3 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-4 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-5 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-7 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-8 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-9 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-10 días antes: 2022-07-24 21:00:00 [15.5]
# Datos pasados final: [16.7, 17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.7): 2022-08-02 21:00:00
# Datos de t-1 días antes: 2022-08-01 21:00:00 [17.4]
# Datos de t-2 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-3 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-4 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-6 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-7 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-8 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-9 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-10 días antes: 2022-07-23 21:00:00 [17.7]
# Datos pasados final: [17.4, 19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 17.4): 2022-08-01 21:00:00
# Datos de t-1 días antes: 2022-07-31 21:00:00 [19.2]
# Datos de t-2 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-3 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-5 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-6 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-7 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-8 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-9 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-10 días antes: 2022-07-22 21:00:00 [19.9]
# Datos pasados final: [19.2, 19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.2): 2022-07-31 21:00:00
# Datos de t-1 días antes: 2022-07-30 21:00:00 [19.4]
# Datos de t-2 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-4 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-5 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-6 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-7 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-8 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-9 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-10 días antes: 2022-07-21 21:00:00 [23.3]
# Datos pasados final: [19.4, 16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.4): 2022-07-30 21:00:00
# Datos de t-1 días antes: 2022-07-29 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-3 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-4 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-5 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-6 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-7 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-8 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-9 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-10 días antes: 2022-07-20 21:00:00 [24.3]
# Datos pasados final: [16.5, 16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-29 21:00:00
# Datos de t-1 días antes: 2022-07-28 21:00:00 [16.5]
# Datos de t-2 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-3 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-4 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-5 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-6 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-7 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-8 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-9 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-10 días antes: 2022-07-19 21:00:00 [17.5]
# Datos pasados final: [16.5, 14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 16.5): 2022-07-28 21:00:00
# Datos de t-1 días antes: 2022-07-27 21:00:00 [14.4]
# Datos de t-2 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-3 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-4 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-5 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-6 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-7 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-8 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-9 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-10 días antes: 2022-07-18 21:00:00 [17.8]
# Datos pasados final: [14.4, 19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5, 17.8]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 14.4): 2022-07-27 21:00:00
# Datos de t-1 días antes: 2022-07-26 21:00:00 [19.7]
# Datos de t-2 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-3 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-4 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-5 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-6 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-7 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-8 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-9 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-10 días antes: 2022-07-17 21:00:00 [16.6]
# Datos pasados final: [19.7, 16.6, 15.5, 17.7, 19.9, 23.3, 24.3, 17.5, 17.8, 16.6]
# ---------------
# ---------------
# Temperatura de fecha a predecir (Temperatura d_t = 19.7): 2022-07-26 21:00:00
# Datos de t-1 días antes: 2022-07-25 21:00:00 [16.6]
# Datos de t-2 días antes: 2022-07-24 21:00:00 [15.5]
# Datos de t-3 días antes: 2022-07-23 21:00:00 [17.7]
# Datos de t-4 días antes: 2022-07-22 21:00:00 [19.9]
# Datos de t-5 días antes: 2022-07-21 21:00:00 [23.3]
# Datos de t-6 días antes: 2022-07-20 21:00:00 [24.3]
# Datos de t-7 días antes: 2022-07-19 21:00:00 [17.5]
# Datos de t-8 días antes: 2022-07-18 21:00:00 [17.8]
# Datos de t-9 días antes: 2022-07-17 21:00:00 [16.6]
# Ya no hay más datos hacía atras, o la fecha 2022-07-16 21:00:00 no existe, se omite esta última instancia y termina la iteracion.
# Predicting: 1it [00:00, ?it/s]

# %% [markdown]
# ###### 9PM pasosPasado=10, pasosFuturo=1, sin Dirección del viento ni Dirección de la ráfaga

# %%
dataENCB90_exp3.show = False
predictions_exp3 = trainer.predict(modelLinReg_exp3, dataENCB90_exp3.val_dataloader())
predictions_list_exp3 = []
for prediction in predictions_exp3[0]:
  predictions_list_exp3.append(float(prediction))
#predictions_list_exp1
test_batch_exp3 = next(iter(dataENCB90_exp3.val_dataloader()))
#test_batch[1]

true_list_exp3 = []
for true in test_batch_exp3[1]:
  true_list_exp3.append(float(true))
true_list_exp3
#dataENCB90.Y_val_horaLocal

lossgraph_exp3 = r2_score(true_list_exp3, predictions_list_exp3) # R2
lossgraph1_exp3 = mean_squared_error(true_list_exp3, predictions_list_exp3) #MSE
lossgraph2_exp3 = mean_squared_error(true_list_exp3, predictions_list_exp3, squared= False) #RMSE
lossgraph3_exp3 = mean_absolute_error(true_list_exp3, predictions_list_exp3) #MAE
# Out:
# Predicting: 1it [00:00, ?it/s]

# %% [markdown]
# #### Gráficas del conjunto de prueba

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.dates as mdates
# Muestra la grafica con las predicciones de dias futuros
fig1 = plt.figure()
axs1 = fig1.add_subplot(1, 1, 1)
axs1.set_xlabel("Instancia")
axs1.set_ylabel("Temperatura (°C)")
plt.scatter(np.arange(1,len(true_list_exp1)+1), true_list_exp1, color="green", marker="o", label='y_true')
plt.scatter(np.arange(1,len(predictions_list_exp1)+1), predictions_list_exp1, color="blue", marker="o", label='y_pred')
axs1.legend(loc="lower left")
axs1.set_title(f'Prediccion temperatura 9 p.m. (info. de 1 dia al pasado, pred. de 1 dia a futuro). MSE: {lossgraph1_exp1:.2f} RMSE: {lossgraph2_exp1:.2f} MAE: {lossgraph3_exp1:.2f}')
fig1.set_size_inches(14,5)
plt.xticks(np.arange(1,len(true_list_exp1)+1))
plt.grid()
fig1.savefig('redes-exp1-pred.png')

# %%
# Muestra la grafica
fig1 = plt.figure()
axs1 = fig1.add_subplot(1, 1, 1)
axs1.set_xlabel("Instancia")
axs1.set_ylabel("Temperatura (°C)")
plt.scatter(np.arange(1,len(true_list_exp2)+1), true_list_exp2, color="green", marker="o", label='y_true')
plt.scatter(np.arange(1,len(predictions_list_exp2)+1), predictions_list_exp2, color="blue", marker="o", label='y_pred')
axs1.legend(loc="lower left")
axs1.set_title(f'Prediccion temperatura 9 p.m. (info. de 5 dias al pasado, pred. de 1 dia a futuro). MSE: {lossgraph1_exp2:.2f} RMSE: {lossgraph2_exp2:.2f} MAE: {lossgraph3_exp2:.2f}')
fig1.set_size_inches(14,5)
plt.xticks(np.arange(1,len(true_list_exp2)+1))
plt.grid()
fig1.savefig('redes-exp2-pred.png')

# %%
# Muestra la grafica
fig1 = plt.figure()
axs1 = fig1.add_subplot(1, 1, 1)
axs1.set_xlabel("Instancia")
axs1.set_ylabel("Temperatura (°C)")
plt.scatter(np.arange(1,len(true_list_exp3)+1), true_list_exp3, color="green", marker="o", label='y_true')
plt.scatter(np.arange(1,len(predictions_list_exp3)+1), predictions_list_exp3, color="blue", marker="o", label='y_pred')
axs1.legend(loc="lower left")
axs1.set_title(f'Prediccion temperatura 9 p.m. (info. de 10 dias al pasado, pred. de 1 dia a futuro). MSE: {lossgraph1_exp3:.2f} RMSE: {lossgraph2_exp3:.2f} MAE: {lossgraph3_exp3:.2f}')
fig1.set_size_inches(14,5)
plt.xticks(np.arange(1,len(true_list_exp3)+1))
plt.grid()
fig1.savefig('redes-exp3-pred.png')

# %%
# import matplotlib.pyplot as plt
# from matplotlib.pyplot import figure
# import matplotlib.dates as mdates
# # Muestra la grafica con las predicciones de dias futuros
# fig1 = plt.figure()
# axs1 = fig1.add_subplot(1, 1, 1)
# axs1.set_xlabel("Fecha (YYYY-MM-DD)")
# axs1.set_ylabel("Temperatura (°C)")
# axs1.plot(dataENCB90.Y_val_horaLocal.to_numpy().reshape(dataENCB90.Y_val_horaLocal.shape[0]),true_list, '-o', label='y_true')
# axs1.plot(dataENCB90.Y_val_horaLocal.to_numpy().reshape(23),predictions_list, '-o', label='y_pred')
# axs1.legend(loc="lower left")
# axs1.set_title('Prediccion temperatura 9 a.m. (1 dia a futuro)')
# fig1.set_size_inches(14,5)
# plt.grid()
# #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%M-%D'))
# plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))
# plt.gca().tick_params(axis='x', labelrotation=45)
# fig1.savefig('redes-exp3-pred.png')

# %% [markdown]
# ## Descargar metricas y modelo

# %%
# !zip -r /content/logs111122_04_40.zip /content/logs

from google.colab import files
files.download("/content/logs111122_04_40.zip")
# Out:
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/20221128-054253/ (stored 0%)
#   adding: content/logs/20221128-054253/ENCB_90_exp2/ (stored 0%)
#   adding: content/logs/20221128-054253/ENCB_90_exp2/version_0/ (stored 0%)
#   adding: content/logs/20221128-054253/ENCB_90_exp2/version_0/checkpoints/ (stored 0%)
#   adding: content/logs/20221128-054253/ENCB_90_exp2/version_0/checkpoints/epoch=69-step=70.ckpt (deflated 25%)
#   adding: content/logs/20221128-054253/ENCB_90_exp2/version_0/hparams.yaml (stored 0%)
#   adding: content/logs/20221128-054253/ENCB_90_exp2/version_0/events.out.tfevents.1669614176.ed89a9aaa640 (deflated 74%)
#   adding: content/logs/20221128-054231/ (stored 0%)
#   adding: content/logs/20221128-054231/ENCB_90_exp1/ (stored 0%)
#   adding: content/logs/20221128-054231/ENCB_90_exp1/version_0/ (stored 0%)
#   adding: content/logs/20221128-054231/ENCB_90_exp1/version_0/checkpoints/ (stored 0%)
#   adding: content/logs/20221128-054231/ENCB_90_exp1/version_0/checkpoints/epoch=49-step=50.ckpt (deflated 27%)
#   adding: content/logs/20221128-054231/ENCB_90_exp1/version_0/hparams.yaml (stored 0%)
#   adding: content/logs/20221128-054231/ENCB_90_exp1/version_0/events.out.tfevents.1669614153.ed89a9aaa640 (deflated 74%)
#   adding: content/logs/20221128-054318/ (stored 0%)
#   adding: content/logs/20221128-054318/ENCB_90_exp3/ (stored 0%)
#   adding: content/logs/20221128-054318/ENCB_90_exp3/version_0/ (stored 0%)
#   adding: content/logs/20221128-054318/ENCB_90_exp3/version_0/checkpoints/ (stored 0%)
#   adding: content/logs/20221128-054318/ENCB_90_exp3/version_0/checkpoints/epoch=69-step=70.ckpt (deflated 23%)
#   adding: content/logs/20221128-054318/ENCB_90_exp3/version_0/hparams.yaml (stored 0%)
#   adding: content/logs/20221128-054318/ENCB_90_exp3/version_0/events.out.tfevents.1669614202.ed89a9aaa640 (deflated 74%)
